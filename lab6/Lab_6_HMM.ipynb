# %% [markdown]
# # Lab 6: Hidden Markov Model
#
#
# In this lab we will look into Hidden Markov Models (HMM) to model sequential data. HMMs use Markov Chains to compute probabilities for a sequence of observed events. Moreover, HMMs are based on the Markov assumption, which states that the present state $z_n$ is sufficient to predict the future $z_{n+1}$, so the past $z_{0:n-1}$ can be discarded.
#
# <img src="hmm.png" width="400">
#
# Often, we are in a situation where the states we are interested in are hidden, we cannot observe them directly. As we will see in Exercise 2, the part-of-speech (POS) tags in a text are hidden and we can only observe the words. From these words we have to infer the tags. Similarly in Exercises 3 where a robot needs to be localised, we cannot observe the robot's position but rather the measurements of its sensors. Both the tags and the robot position are called hidden variables because they are not observed.
# An HMM is specified by the following components:
#
# * A set of $N$ states.
#
# * A transition probability matrix $A$ where each element $a_{ij}$ represents the probability of moving from state $i$ to state $j$, s.t.  $ \sum^{N}_{j=1} a_{ij} = 1$ $ \forall i$
#
# * An emission probability distribution, the probabilities of observations $x_n$ being generated from a state $z_n$
#
# * An initial probability distribution over states. $\pi_n$ is the probability that the Markov chain will start in state $n$. Also, $\sum^{N}_{n=1} \pi_n = 1 $
#
#
# ### Additional packages
#
# For this lab we need `hmmlearn`, `nltk`, `ipywidgets` which you can install with conda:
#
# ```python
# conda install -c conda-forge hmmlearn
# conda install -c anaconda nltk
# conda install -c conda-forge ipywidgets
# ```
#
# Let's import the libraries:

# %%
import numpy as np
import matplotlib.pyplot as plt

from hmmlearn import hmm
from IPython import display

import nltk
from nltk.corpus import brown
from nltk.probability import ConditionalFreqDist,ConditionalProbDist,MLEProbDist
import itertools

from sklearn.model_selection import train_test_split


# interactive display
import ipywidgets as widgets
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## 1) HMM with 2 states
# We will start with a warm up exercise where you have to implement an HMM with 2 states and then analyse how the transition probability and emission noise influence the output. Your task is to create a function `hmm_model` that has three arguments:
# 1. `switch_prob`: The probability of switching to the other state.
# 2. `noise_level`: The variance of the emission distribution, i.e. the measurement/observation noise.
# 3. `startprob`: The probabilities of starting in each state (`shape=(2,1)`).
#
# Your function should create a [hmm.GaussianHMM](https://hmmlearn.readthedocs.io/en/latest/api.html#hmmlearn.hmm.GaussianHMM) model with two states (hidden states) and `covariance_type="full"`. Modify the following model attributes:
# * `startprob_`: Using the `startprob` argument.
# * `transmat_`: Implement a transition matrix with probability of transition for both states being $p_{transition} = $ `switch_prob`.
# * `means_`: Add mean $\mu_1 = 1$ and $\mu_2 = -1$ for each state
# * `covars_`: Using the the `noise_level` argument. (note: the shape should be `(2, 1, 1)`, i.e. two $1\times1$ covariance matrices)

# %%
def plot_hmm(model, states, observations):
    """Plots HMM states and observations for 1d states and observations.

    Args:
    model (hmmlearn model):               hmmlearn model used to get state means.
    states (numpy array of floats):       Samples of the states.
    observations (numpy array of floats): Samples of the states.
    """

    nsteps = states.size
    fig, ax1 = plt.subplots(figsize=(8,4))
    states_forplot = list(map(lambda s: model.means_[s], states))
    ax1.step(np.arange(nstep), states_forplot, "--", where="mid", alpha=1.0, c="green")
    ax1.set_xlabel("Time")
    ax1.set_ylabel("Latent State", c="green")
    ax1.set_yticks([-1, 1])
    ax1.set_yticklabels(["State 1", "State 0"])

    ax2 = ax1.twinx()
    ax2.plot(np.arange(nstep), observations.flatten(), c="blue")
    ax2.set_ylabel("Observations", c="blue")
    ax1.set_ylim(ax2.get_ylim())
    plt.show(fig)

# %%
# write your code here

def hmm_model(switch_prob, noise_level, startprob):
    transitionMatrix = [[1-switch_prob, switch_prob], 
                        [switch_prob, 1-switch_prob]]
    model = hmm.GaussianHMM(n_components=2 , covariance_type="full")
    model.transmat_ = transitionMatrix
    model.means_ = [[1],
                    [-1]]
    model.startprob_ = startprob
    model.covars_ = [[[noise_level]],
                    [[noise_level]]]
    return model

# %% [markdown]
# Next, execute the cell below to run your `hmm_model` and visualise the output with the provided `plot_hmm` function.

# %%
np.random.seed(101)
nstep = 50
model = hmm_model(switch_prob=0.1, noise_level=1e-8, startprob=np.array([1.0, 0.0]))
observations, states = model.sample(nstep)
plot_hmm(model, states, observations)

# %% [markdown]
# Run the cell below and experiment with the interactive widget window. Try changing the value of `switch_prob` and `noise_level`, how does that changes the output?

# %%
#@title

#@markdown Make sure you execute this cell to enable the widget!
np.random.seed(101)
nstep = 50

@widgets.interact
def plot(switch_prob=(0., 1, .01), log10_noise_level=(-8., 1., .01)):
    model = hmm_model(switch_prob=switch_prob,
                    noise_level=10.**log10_noise_level,
                    startprob=[1.0, 0.0])

    observations, states = model.sample(nstep)
    observations = observations.flatten()
    plot_hmm(model, states, observations)
# Out:
# interactive(children=(FloatSlider(value=0.5, description='switch_prob', max=1.0, step=0.01), FloatSlider(value…

# %% [markdown]
# ## 2) HMM Part-of-Speech Tagging
#
# Part-of-speech (POS) tagging enables the extraction of meaningful information about words in a sentence and their relation to neighbouring words. Knowing whether a word is a noun or a verb provides us information about their most likely neighboring words (such as nouns are preceded by determiners and adjectives, verbs by nouns) and syntactic structure (nouns are generally part of noun phrases), making POS tagging a key aspect of parsing. Parts of speech are useful features for labeling named entities like people or organisations in information extraction, or for coreference resolution. A word’s part of speech can even play a role in speech recognition or synthesis, e.g., the word content is pronounced CONtent when it is a noun and conTENT when it is an adjective.
#
# Part-of-speech tagging is the process of assigning a POS tag to each word in a given text. The input to a tagging algorithm is a sequence of tokenised words and the output is a sequence of tags, one per token. Particularly, words are ambiguous as they have more than one possible POS and the goal is to find the correct tag for each situation.
# For example, "book" can be a verb ("book that flight") or a noun ("hand me that book"). The goal of POS-tagging is to resolve these ambiguities, choosing the proper tag for the context.
#
#
# In this section we introduce the use of the Hidden Markov Model for part-of-speech tagging. The HMM can be used as a sequence tagger to assign a tag or class label to each unit in an observed sequence, thus mapping a sequence of observations to a sequence of labels. A HMM is a probabilistic sequence model: given a sequence of units (words, letters, morphemes, sentences), it computes a probability distribution over possible sequences of labels and chooses the best label sequence.

# %% [markdown]
# ### 2.1) Brown corpus dataset
# The Brown corpus is a common dataset in Natural Language Processing (NLP), it is available from the NLTK library and it supports POS tagged information. Run the cell below to download the dataset and the universal tagset.

# %%
# Brown dataset
nltk.download('brown')
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     /Users/NunoAlberto/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     /Users/NunoAlberto/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# True

# %% [markdown]
# First we need to get the dataset and split it into training and testing.
# Run the following cells to achieve that and to prepare the dataset in the correct format.

# %%
nltk_data = list(brown.tagged_sents(tagset='universal'))
train_set,test_set = train_test_split(nltk_data,
                                      train_size=0.80,
                                      test_size=0.20,
                                      random_state=101
                                      )

print(train_set[:5])
# Out:
# [[('A', 'DET'), ('Newfoundland', 'NOUN'), ('sat', 'VERB'), ('solemnly', 'ADV'), ('beside', 'ADP'), ('a', 'DET'), ('doghouse', 'NOUN'), ('half', 'PRT'), ('his', 'DET'), ('size', 'NOUN'), ('.', '.')], [('Parker', 'NOUN'), (',', '.'), ('along', 'ADV'), ('with', 'ADP'), ('Garrison', 'NOUN'), ('and', 'CONJ'), ('Charles', 'NOUN'), ('Sumner', 'NOUN'), (',', '.'), ('showed', 'VERB'), ('a', 'DET'), ('magnificent', 'ADJ'), ('moral', 'ADJ'), ('bravery', 'NOUN'), ('when', 'ADV'), ('facing', 'VERB'), ('mobs', 'NOUN'), ('mobilized', 'VERB'), ('in', 'ADP'), ('defense', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('Mexican', 'ADJ'), ('War', 'NOUN'), ('and', 'CONJ'), ('slavery', 'NOUN'), ('.', '.')], [('Neither', 'CONJ'), ('was', 'VERB'), ('his', 'DET'), ('wife', 'NOUN'), ('.', '.')], [('many', 'ADJ'), ('of', 'ADP'), ('their', 'DET'), ('gifted', 'ADJ'), ('members', 'NOUN'), ('were', 'VERB'), ('prominent', 'ADJ'), ('in', 'ADP'), ('the', 'DET'), ('Vatican', 'NOUN'), ('as', 'ADP'), ('physicians', 'NOUN'), (',', '.'), ('musicians', 'NOUN'), (',', '.'), ('bankers', 'NOUN'), ('.', '.')], [('Ephesians', 'NOUN'), ('2', 'NUM'), (':', '.'), ('8-10', 'NUM'), ('.', '.')]]

# %%
# create list of train and test tagged words
train_tagged_words = [ tup for sent in train_set for tup in sent ]
test_tagged_words = [ tup for sent in test_set for tup in sent ]
print(f'Number of tagged words in the training set: {len(train_tagged_words)}')
print(f'Number of tagged words in the test set: {len(test_tagged_words)}')

print(train_tagged_words[:5])
# Out:
# Number of tagged words in the training set: 927092
# Number of tagged words in the test set: 234100
# [('A', 'DET'), ('Newfoundland', 'NOUN'), ('sat', 'VERB'), ('solemnly', 'ADV'), ('beside', 'ADP')]

# %% [markdown]
# Let's explore the different types of tags by running the next cell.

# %%
tags = {tag for word, tag in train_tagged_words}
print(f'Number of possible tags: {len(tags)}')
print(f'Possible tags: {tags}')
# Out:
# Number of possible tags: 12
# Possible tags: {'CONJ', 'DET', 'PRT', 'ADJ', 'VERB', 'PRON', 'ADV', 'NOUN', '.', 'ADP', 'X', 'NUM'}

# %% [markdown]
# The next cell, explores the structure of the dataset in terms of words and sentences.

# %%
print('Words example: {}'.format(train_tagged_words[0:5]))
print('Sentence example: {}'.format(train_set[0]))
# Out:
# Words example: [('A', 'DET'), ('Newfoundland', 'NOUN'), ('sat', 'VERB'), ('solemnly', 'ADV'), ('beside', 'ADP')]
# Sentence example: [('A', 'DET'), ('Newfoundland', 'NOUN'), ('sat', 'VERB'), ('solemnly', 'ADV'), ('beside', 'ADP'), ('a', 'DET'), ('doghouse', 'NOUN'), ('half', 'PRT'), ('his', 'DET'), ('size', 'NOUN'), ('.', '.')]

# %% [markdown]
# ### 2.2) POS tagging model
#
# Two of the main components of HMMs are the transition model and the emission model. You already got a taste of how the two models operate in the exercise 1. Your task now is two implement both models for POS tagging model.
#
# Specifically, the transition model $P(tag_{t+1}|tag_t)$ will estimate the probability of the next tag given the current tag while the emission model $P(word|tag_t)$ will estimate the probability of observing a word given the current tag.
#
# Note: the provided hints link to the `ntlk.probability` functions, however you are free to use any other libraries such as `numpy`.
#
# #### 2.2.1) Emission Model
# Given the tagged words, the main steps are:
# 1. Create a list of tuples ($tag, word$) from the input `words` which will be utilised in step 2. (careful: `words` contains tuples of ($word, tag$))
# 2. Calculate the frequency for each word given the corresponding tag. (hint: [ConditionalFreqDist](https://www.nltk.org/api/nltk.html?highlight=conditionalfreqdist#nltk.probability.ConditionalFreqDist))
# 3. Calculate the conditional probability distribution given the frequency distribution of step 2. (hint: [ConditionalProbDist](https://www.nltk.org/api/nltk.html?highlight=conditionalprobdist#nltk.probability.ConditionalProbDist) with `probdist_factory`=`MLEProbDist`)
#
# Implement these steps in the cell below in a function `emission_model` that has one argument, `words`, containing a list of `(word, tag)` pairs.

# %%
# write your code here

def emission_model(words):
    reversed = [(tag, word) for word, tag in words]
    cfdist = ConditionalFreqDist(reversed)
    cpdist = ConditionalProbDist(cfdist, probdist_factory=MLEProbDist)
    return cpdist

# %% [markdown]
# #### 2.2.2) Transition Model
# Given the tagged sentences, the main steps are:
# 1. Create chain of tuples ($tag_{t}, tag_{t+1}$) to be passed to `ConditionalFreqDist()`. To achieve this efficiently:
#     * Create a generator expression (similar to list comprehension but replacing `[]` with `()` which iterates over each sentence and for each sentence creates a pair of ($tag_{t}, tag_{t+1}$) (if you are curious about generator expressions, you can read [this](https://wiki.python.org/moin/Generators) and [this](https://realpython.com/introduction-to-python-generators/))
#     * Create a chain from the ouput of the generator (hint: [itertools.chain.from_iterable()](https://docs.python.org/3.4/library/itertools.html#itertools.chain.from_iterable))
# 2. Calculate the frequency of the next tag given the previous tag. (hint: [ConditionalFreqDist](https://www.nltk.org/api/nltk.html))
# 3. Calculate the conditional probability distribution of the next tag given the previous tag. (hint: [ConditionalProbDist](https://www.nltk.org/api/nltk.html))
#
# Implement these steps in the cell below in a function `transition_model` that has one argument, `sentences`, containing the dataset of sentences.

# %%
# write your code here

def transition_model(sentences):
    tags = []
    for sentence in sentences:
        for index, tuple in enumerate(sentence):
            if index < len(sentence)-1:
                tags.append((tuple[1], sentence[index+1][1]))
    """ chain = itertools.chain.from_iterable(tags)
    print(chain[:5]) """
    cfdist = ConditionalFreqDist(tags)
    cpdist = ConditionalProbDist(cfdist, probdist_factory=MLEProbDist)
    return cpdist

# %% [markdown]
# Utilising the previously created models, the cell below trains the emission and transition models, the former using tagged words and the later on tagged sentences.

# %%
emission_p = emission_model(train_tagged_words)
transition_p = transition_model(train_set)

# %% [markdown]
# Based on the Brown corpus, the trained HMM gives the following probabilities:
# * The probability of observing the world `city` given the tag `NOUN`.
# * The probability of the tag `VERB` given the tag `NOUN`.

# %%
p_city_NOUN = emission_p['NOUN'].prob('city')
p_VERB_NOUN = transition_p['NOUN'].prob('VERB')
print('p(city|NOUN) = ', p_city_NOUN)
print('p(VERB|NOUN) = ', p_VERB_NOUN)
# Out:
# p(city|NOUN) =  0.0009174311926605505
# p(VERB|NOUN) =  0.15875670429120206

# %% [markdown]
# ### 2.3) Viterbi algorithm
#
# The goal of the Viterbi algorithm is to find the most likely sequence of hidden states for a given sequence of observations. Specifically, we will utilise the Viterbi algorithm to find the tags of a sequence of untagged sentences, known as $decoding$.
# The benefit of this algorithm comes from its ability to efficiently determine the most probable path amongst the exponentially many possibilities. Doing so, it can reduce the complexity from $O(N^T)$ to $O(NT)$ where $N$ is the total number of words and $T$ is the total number of tags.
#
# Your task is to implement Viterbi algorithm and perform HMM decoding.
# Complete the missing `to-do` lines.

# %%
def viterbi(observed_seq, states, start_p, transition_p, emit_p):
    eps = 0.00000001
    
    # Initialise the list, V, that will contain a dictionary for each element in the sequence. Each dictionary 
    # has the possible states (tags) as keys and its values are a dictionary with the keys:
    # 'prob': the probability of the sequence until this point
    # 'prev': the previous state used for backtracking.
    V = [dict()] 
    for state in states:
        # Compute the probability of each possible state for the first token in the sequence.
        V[0][state] = {"prob": start_p[state] * emit_p[state].prob(observed_seq[0]), "prev": None}

    # Run Viterbi for t > 0
    for t in range(1, len(observed_seq)):
        V.append({})
        for state in states:
            # In the forward pass, for each element of the observed_seq we want to store the maximum 
            # probability for each state as well as the previous state. This probability is the product of
            # the maximum transition probability and the emission probability.
            
            # First we calculate the max_transition_prob by going through all the combinations between states.
            # The next line just initialises the max_transition_prob:
            max_transition_prob = 0.0
            
            for prev_state in states:
                # Next, we calculate each possible transition probability that results in tag_t = state.
                # The transition probability is given by the product between
                # the prob of the sequence until t-1 where tag_{t-1} = prev_state,
                # and the transition probability from prev_state to state.
                #transition_prob = # TO-DO
                transition_prob = V[t-1][prev_state]["prob"] * transition_p[prev_state].prob(state)
                print("transition_prob: ", transition_prob)

                #update the maximum transition_prob accordingly
                if transition_prob > max_transition_prob:
                    max_transition_prob = transition_prob
                    prev_state_selected = prev_state
                    
            # Calculate the max_prob given by the product of the maximum transition probability and the 
            # emission probability. Remember to add eps to each probability before multiplying them together
            #max_prob = # TO-DO
            max_prob = (max_transition_prob + eps) * (emit_p[state].prob(observed_seq[t]) + eps)
            print("max_prob: ", max_prob)
            
            V[t][state] = {"prob": max_prob, "prev": prev_state_selected}

    most_likely_seq = []
    max_prob = 0.0
    previous = None
    # Get most probable final state before backtracking
    for state, data in V[-1].items():
        if data["prob"] > max_prob:
            max_prob = data["prob"]
            best_state = state
    most_likely_seq.append(best_state)
    previous = best_state

    # Backtrack until the first observation
    for t in range(len(V) - 2, -1, -1):
        # add the most likely tag to the most_likely_seq. Remember: we are backtracking hence we need to 
        # add before the last tag (hint: most_likely_seq.insert() )
        # TO-DO        
        most_likely_seq.insert(0, V[t + 1][previous]["prev"])

        previous = V[t + 1][previous]["prev"]

    # print ('The steps of states are ' + ' '.join(most_likely_seq) + ' with highest probability of %s' % max_prob)

    return list(zip(observed_seq, most_likely_seq))

# %% [markdown]
# Run the cell below to get `n=10` random sentences as test data (untagged words).

# %%
import random, time
# Let's test our Viterbi algorithm on a few sample sentences of test dataset
random.seed(1234)      #define a random seed to get same sentences when run multiple times

n = 10
# n = 11468 # whole test set
# choose random n numbers
rndom = [random.randint(1,len(test_set)) for x in range(n)]

# list of 10 sentences on which we test the model
test_run = [test_set[i] for i in rndom]
 
# list of tagged words
test_run_base = [tup for sent in test_run for tup in sent]
 
# list of untagged words
test_tagged_words = [tup[0] for sent in test_run for tup in sent]

# %% [markdown]
# Run the cell below to check your implementation of the Viterbi algorithm on the test set and its POS tagging accuracy.

# %%
possible_tags = list(set([pair[1] for pair in train_tagged_words]))
start_pr = {}
for tag in possible_tags:
    start_pr[tag] = 1.0/len(possible_tags)
    
start = time.time()
predicted_tags = viterbi(test_tagged_words, possible_tags, start_pr, transition_p, emission_p)
end = time.time()
difference = end-start

print("Time taken in seconds: ", difference)

# accuracy 
predicted_correct = [i for i, j in zip(predicted_tags, test_run_base) if i == j]  

accuracy = len(predicted_correct)/len(predicted_tags)
print('Viterbi Algorithm Accuracy: ', accuracy*100)
# Out:
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  9.902010291476917e-05
# transition_prob:  0.0
# transition_prob:  9.063512316689527e-08
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# max_prob:  9.903010291476917e-13
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.00015131161793717533
# transition_prob:  0.0
# transition_prob:  2.3552162467025456e-08
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# max_prob:  1.5132161793717532e-12
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.00020783095757841437
# transition_prob:  0.0
# transition_prob:  2.6967019063738288e-08
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# max_prob:  2.0784095757841438e-12
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  8.566907780266546e-05
# transition_prob:  0.0
# transition_prob:  1.984756046210669e-08
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# max_prob:  8.567907780266545e-13
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.006191092861567691
# transition_prob:  0.0
# transition_prob:  2.403438161068248e-07
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# max_prob:  2.888892055311292e-06
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  7.343063811657039e-05
# transition_prob:  0.0
# transition_prob:  2.9933460147751446e-08
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# max_prob:  7.344063811657038e-13
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0004679534301792349
# transition_prob:  0.0
# transition_prob:  4.013663773671766e-08
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# max_prob:  4.679634301792349e-12
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  7.921608233181534e-05
# transition_prob:  0.0
# transition_prob:  2.2776748565064806e-07
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# max_prob:  7.922608233181534e-13
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0008956312679369569
# transition_prob:  0.0
# transition_prob:  4.3051338569265485e-07
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# max_prob:  8.95641267936957e-12
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.00048375214322855765
# transition_prob:  0.0
# transition_prob:  3.712328549137592e-07
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# max_prob:  4.837621432285576e-12
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  2.2251708520172846e-07
# transition_prob:  0.0
# transition_prob:  5.518960156303564e-10
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# max_prob:  2.3251708520172847e-15
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  9.123200493270868e-06
# transition_prob:  0.0
# transition_prob:  1.2431457752073775e-08
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# transition_prob:  0.0
# max_prob:  9.133200493270867e-14
# transition_prob:  2.2732692346146264e-16
# transition_prob:  8.997928120092209e-16
# transition_prob:  2.5032642915618006e-14
# transition_prob:  3.2390011161244014e-14
# transition_prob:  4.220922306774987e-08
# transition_prob:  8.316432287928804e-15
# transition_prob:  7.962359726752363e-14
# transition_prob:  4.7431169414095755e-14
# transition_prob:  1.005332923464566e-12
# transition_prob:  9.208059413768931e-15
# transition_prob:  5.1479797461637293e-17
# transition_prob:  3.617260222100928e-15
# max_prob:  5.220922306774987e-16
# transition_prob:  1.5042547278192787e-13
# transition_prob:  8.873341423044778e-15
# transition_prob:  1.7470334006843893e-13
# transition_prob:  5.037306840668341e-15
# transition_prob:  4.69894969208174e-07
# transition_prob:  1.270825608043053e-14
# transition_prob:  3.428093276852099e-13
# transition_prob:  1.2325316819890615e-14
# transition_prob:  9.870407503547577e-13
# transition_prob:  2.2048279718114535e-12
# transition_prob:  1.2869949365409323e-17
# transition_prob:  1.167596653969287e-15
# max_prob:  4.7989496920817405e-15
# transition_prob:  2.4941011031200474e-14
# transition_prob:  3.1008244598471615e-15
# transition_prob:  2.2056734317257822e-14
# transition_prob:  1.671411735427867e-14
# transition_prob:  1.8845386671367078e-07
# transition_prob:  1.7455163498708996e-14
# transition_prob:  1.35140967839375e-13
# transition_prob:  1.411237945194857e-14
# transition_prob:  2.6112384029907584e-13
# transition_prob:  7.023238043774666e-14
# transition_prob:  1.930492404811399e-17
# transition_prob:  4.807750928108829e-16
# max_prob:  1.9845386671367078e-15
# transition_prob:  1.1025355787880938e-13
# transition_prob:  3.6329480859030757e-13
# transition_prob:  3.9824659183937733e-14
# transition_prob:  4.834789161068952e-14
# transition_prob:  1.6590128841102436e-07
# transition_prob:  7.195115574949639e-15
# transition_prob:  6.441893393609743e-13
# transition_prob:  1.03866246311732e-14
# transition_prob:  4.172825261760972e-13
# transition_prob:  3.9757889259723216e-13
# transition_prob:  6.434974682704662e-18
# transition_prob:  5.433521683830931e-15
# max_prob:  1.7590128841102438e-15
# transition_prob:  1.9397481626218805e-13
# transition_prob:  9.688692140388519e-14
# transition_prob:  1.2926821790935744e-12
# transition_prob:  1.5099102947346833e-14
# transition_prob:  5.318401776858916e-07
# transition_prob:  5.199732484203216e-13
# transition_prob:  1.1299663318646735e-12
# transition_prob:  1.2577671724902435e-13
# transition_prob:  1.1084565839493914e-12
# transition_prob:  2.002334374339571e-13
# transition_prob:  1.351344683367979e-16
# transition_prob:  4.204874224425341e-15
# max_prob:  5.418401776858916e-15
# transition_prob:  6.680164022288982e-14
# transition_prob:  1.54764363665586e-14
# transition_prob:  1.4266855927432638e-14
# transition_prob:  3.2172112392054797e-15
# transition_prob:  1.5790771844095706e-07
# transition_prob:  6.167241921385405e-15
# transition_prob:  2.237391776429498e-13
# transition_prob:  1.5664777293938305e-14
# transition_prob:  6.661297402269796e-13
# transition_prob:  3.36429007126703e-13
# transition_prob:  1.501494092631088e-17
# transition_prob:  8.012918213514715e-16
# max_prob:  1.6790771844095707e-15
# transition_prob:  9.10606704837059e-14
# transition_prob:  2.6979941393938024e-14
# transition_prob:  7.317234083026801e-14
# transition_prob:  8.25451807987382e-15
# transition_prob:  2.9893571468705745e-07
# transition_prob:  3.930215078991972e-14
# transition_prob:  4.521743734733682e-13
# transition_prob:  2.10043038248751e-14
# transition_prob:  6.275811338076519e-13
# transition_prob:  7.379003975670284e-14
# transition_prob:  2.144991560901554e-17
# transition_prob:  1.900206319204918e-15
# max_prob:  3.089357146870575e-15
# transition_prob:  2.4158356908997437e-13
# transition_prob:  9.474403021466937e-13
# transition_prob:  7.579814253470347e-14
# transition_prob:  5.595127689792733e-13
# transition_prob:  2.8249236603895376e-07
# transition_prob:  6.653145830343044e-15
# transition_prob:  1.521509892739836e-13
# transition_prob:  1.1919527244449576e-13
# transition_prob:  1.1995491507109872e-12
# transition_prob:  1.2498266461570637e-12
# transition_prob:  1.308444852149948e-16
# transition_prob:  3.464633208510172e-14
# max_prob:  5.845357487240217e-11
# transition_prob:  2.0037244539388923e-14
# transition_prob:  1.9657012200816824e-14
# transition_prob:  1.623620720575923e-13
# transition_prob:  8.635200047222038e-14
# transition_prob:  2.327854520315378e-07
# transition_prob:  7.522166282901896e-14
# transition_prob:  7.973838882321732e-13
# transition_prob:  2.2529624960318508e-13
# transition_prob:  1.551397258984213e-12
# transition_prob:  4.721223190332434e-14
# transition_prob:  6.413524767095646e-16
# transition_prob:  2.5084249683640827e-14
# max_prob:  2.4278545203153777e-15
# transition_prob:  7.164045616514094e-14
# transition_prob:  1.3787594473248985e-14
# transition_prob:  1.8721966152624796e-13
# transition_prob:  7.521352809425401e-14
# transition_prob:  4.919913388028513e-07
# transition_prob:  4.062904223361173e-14
# transition_prob:  6.585904618025449e-13
# transition_prob:  1.942735643561669e-13
# transition_prob:  9.35601686374827e-13
# transition_prob:  9.969817056180724e-14
# transition_prob:  1.2869949365409324e-16
# transition_prob:  1.1943063813476694e-14
# max_prob:  5.019913388028514e-15
# transition_prob:  5.845549460437611e-16
# transition_prob:  2.2010316478379404e-15
# transition_prob:  1.7505344696236366e-16
# transition_prob:  4.357975383784315e-16
# transition_prob:  5.752196752653882e-10
# transition_prob:  1.8688611882986078e-17
# transition_prob:  5.217797986076254e-16
# transition_prob:  2.8881820316088144e-16
# transition_prob:  1.7678341797398645e-14
# transition_prob:  2.0508859603394437e-15
# transition_prob:  1.1604404344477409e-15
# transition_prob:  2.2894052038613473e-17
# max_prob:  1.0575219675265389e-16
# transition_prob:  1.8770708822960775e-14
# transition_prob:  1.461817245356519e-14
# transition_prob:  1.1115893882110093e-14
# transition_prob:  6.216523709221743e-15
# transition_prob:  2.5904720548158516e-08
# transition_prob:  7.662330872024292e-16
# transition_prob:  6.334406755096573e-14
# transition_prob:  6.505630026198854e-15
# transition_prob:  1.7923874322362516e-13
# transition_prob:  1.465337091254774e-13
# transition_prob:  2.144991560901554e-18
# transition_prob:  2.029939280757061e-15
# max_prob:  3.590472054815852e-16
# transition_prob:  1.1984802304527088e-19
# transition_prob:  2.8535648091746924e-18
# transition_prob:  2.3902049136742965e-17
# transition_prob:  6.649750255286987e-17
# transition_prob:  7.916755797422345e-17
# transition_prob:  1.9013903022171133e-17
# transition_prob:  5.256516073996496e-17
# transition_prob:  3.4995058837070105e-12
# transition_prob:  2.725200557448102e-16
# transition_prob:  9.555038850384345e-18
# transition_prob:  2.3413770498742556e-18
# transition_prob:  1.4220285377529358e-17
# max_prob:  1.0003499505883706e-16
# transition_prob:  7.930514896367068e-17
# transition_prob:  2.8140539118168886e-17
# transition_prob:  1.6681290236691942e-16
# transition_prob:  1.0341716859231443e-17
# transition_prob:  8.813343272600346e-16
# transition_prob:  2.9054952932755886e-17
# transition_prob:  2.2631265141649396e-16
# transition_prob:  9.093707632041205e-13
# transition_prob:  2.675615152263126e-16
# transition_prob:  2.287910620729757e-15
# transition_prob:  5.853442624685639e-19
# transition_prob:  4.590092115531629e-18
# max_prob:  1.0000909370763204e-16
# transition_prob:  1.314904024268115e-17
# transition_prob:  9.833823342386632e-18
# transition_prob:  2.106054679181548e-17
# transition_prob:  3.4314500723760313e-17
# transition_prob:  3.534638008990117e-16
# transition_prob:  3.990783241057941e-17
# transition_prob:  8.921609850361025e-17
# transition_prob:  1.041221532912978e-12
# transition_prob:  7.078399787143867e-17
# transition_prob:  7.287888723156787e-17
# transition_prob:  8.78016393702846e-19
# transition_prob:  1.8900379299247885e-18
# max_prob:  1.0001041221532914e-16
# transition_prob:  5.812629117695638e-17
# transition_prob:  1.152137766953548e-15
# transition_prob:  3.802598726300017e-17
# transition_prob:  9.925943000768703e-17
# transition_prob:  3.1116421752650606e-16
# transition_prob:  1.6450230704575025e-17
# transition_prob:  4.252748849905684e-16
# transition_prob:  7.663326554593599e-13
# transition_prob:  1.13114625653512e-16
# transition_prob:  4.1256051836273137e-16
# transition_prob:  2.9267213123428196e-19
# transition_prob:  2.136042866835634e-17
# max_prob:  1.0000766332655459e-16
# transition_prob:  1.0226460594991472e-16
# transition_prob:  3.07263078452518e-16
# transition_prob:  1.2342984744774714e-15
# transition_prob:  3.0998835776525806e-17
# transition_prob:  9.975186710351756e-16
# transition_prob:  1.188817581541275e-15
# transition_prob:  7.459705904224647e-16
# transition_prob:  9.279896900781591e-12
# transition_prob:  3.004742439027832e-16
# transition_prob:  2.0777866300108503e-16
# transition_prob:  6.146114755919921e-18
# transition_prob:  1.6530331736326323e-17
# max_prob:  1.0009279896900781e-16
# transition_prob:  3.521819762916032e-17
# transition_prob:  4.9081314717804706e-17
# transition_prob:  1.3622496535975885e-17
# transition_prob:  6.605015093300489e-18
# transition_prob:  2.961714892071395e-16
# transition_prob:  1.4100197746778592e-17
# transition_prob:  1.4770603489709683e-16
# transition_prob:  1.1557585651853188e-12
# transition_prob:  1.8057074398233488e-16
# transition_prob:  3.491063739972244e-16
# transition_prob:  6.82901639546658e-19
# transition_prob:  3.150063216541314e-18
# max_prob:  1.0001155758565187e-16
# transition_prob:  4.800769380270566e-17
# transition_prob:  8.556304327817655e-17
# transition_prob:  6.986752824586404e-17
# transition_prob:  1.694673195253193e-17
# transition_prob:  5.606833957845496e-16
# transition_prob:  8.985671473174357e-17
# transition_prob:  2.985122431012689e-16
# transition_prob:  1.5497126831639053e-12
# transition_prob:  1.7012120221852116e-16
# transition_prob:  7.657060678739819e-17
# transition_prob:  9.755737707809399e-19
# transition_prob:  7.470149913512258e-18
# max_prob:  1.0001549712683165e-16
# transition_prob:  1.273642062048243e-16
# transition_prob:  3.004672041069758e-15
# transition_prob:  7.237473619727065e-17
# transition_prob:  1.1486937006085777e-15
# transition_prob:  5.298422747504183e-16
# transition_prob:  1.5211122417736907e-17
# transition_prob:  1.0044561514923842e-16
# transition_prob:  8.794313156985131e-12
# transition_prob:  3.2516711010899257e-16
# transition_prob:  1.2969227959605769e-15
# transition_prob:  5.951000001763734e-18
# transition_prob:  1.3620273336283395e-16
# max_prob:  1.0008794313156986e-16
# transition_prob:  1.0563747174133163e-17
# transition_prob:  6.233941583120097e-17
# transition_prob:  1.550290249953084e-16
# transition_prob:  1.7728281547237208e-16
# transition_prob:  4.3661205845182634e-16
# transition_prob:  1.7197968463873887e-16
# transition_prob:  5.264094275413791e-16
# transition_prob:  1.6622519765012635e-11
# transition_prob:  4.2054413780036226e-16
# transition_prob:  4.899129010560701e-17
# transition_prob:  2.9169655746350105e-17
# transition_prob:  9.861197897877428e-17
# max_prob:  1.0016622519765013e-16
# transition_prob:  3.776924840540966e-17
# transition_prob:  4.372539307596913e-17
# transition_prob:  1.7876392693529092e-16
# transition_prob:  1.544152532569214e-16
# transition_prob:  9.22778246237142e-16
# transition_prob:  9.289039364089897e-17
# transition_prob:  4.3478208313226586e-16
# transition_prob:  1.4333643675905134e-11
# transition_prob:  2.5361769994275225e-16
# transition_prob:  1.0345501155279777e-16
# transition_prob:  5.85344262468564e-18
# transition_prob:  4.695094222749673e-17
# max_prob:  1.2181232365083563e-10
# transition_prob:  3.081806306878394e-19
# transition_prob:  6.98025853321194e-18
# transition_prob:  1.671471967604403e-19
# transition_prob:  8.947032397299467e-19
# transition_prob:  1.078881194197594e-18
# transition_prob:  4.272787195993513e-20
# transition_prob:  3.4446370078614e-19
# transition_prob:  2.1309215306482025e-14
# transition_prob:  4.792146541366793e-18
# transition_prob:  2.1281677439492403e-18
# transition_prob:  5.2778540999248853e-17
# transition_prob:  9.000180618689469e-20
# max_prob:  9.208222752713375e-12
# transition_prob:  9.896022474309511e-18
# transition_prob:  4.635945289982269e-17
# transition_prob:  1.061384699428796e-17
# transition_prob:  1.2762678566736005e-17
# transition_prob:  4.858685653869164e-17
# transition_prob:  1.7518427503573402e-18
# transition_prob:  4.1817893275437394e-17
# transition_prob:  4.799900747785075e-13
# transition_prob:  4.8587041322191096e-17
# transition_prob:  1.5205541370543452e-16
# transition_prob:  9.7557377078094e-20
# transition_prob:  7.980160148571328e-18
# max_prob:  1.0000479990074779e-16
# transition_prob:  2.296336870898732e-20
# transition_prob:  5.946768537132897e-20
# transition_prob:  1.2045387809982369e-18
# transition_prob:  3.780677166971404e-18
# transition_prob:  1.4624427629238808e-18
# transition_prob:  1.1325328428535278e-18
# transition_prob:  1.7017555539944371e-18
# transition_prob:  5.992077415994444e-18
# transition_prob:  1.1243385897382728e-17
# transition_prob:  2.3186086989370087e-13
# transition_prob:  2.0387209046597876e-13
# transition_prob:  3.9607516003471296e-18
# max_prob:  1.0000231860869894e-16
# transition_prob:  1.5195189122861328e-17
# transition_prob:  5.864428665080287e-19
# transition_prob:  8.406501422631051e-18
# transition_prob:  5.879723492757268e-19
# transition_prob:  1.6280671547775722e-17
# transition_prob:  1.7306119845851658e-18
# transition_prob:  7.326693309137255e-18
# transition_prob:  1.5570826836813087e-18
# transition_prob:  1.1038810918910385e-17
# transition_prob:  5.55180313830017e-11
# transition_prob:  5.096802261649469e-14
# transition_prob:  1.2784704532766053e-18
# max_prob:  1.0055518031383003e-16
# transition_prob:  2.5194095955003238e-18
# transition_prob:  2.0493479266427212e-19
# transition_prob:  1.0613418629774675e-18
# transition_prob:  1.9509311538309103e-18
# transition_prob:  6.529449572622082e-18
# transition_prob:  2.3770464611802136e-18
# transition_prob:  2.8883007109079896e-18
# transition_prob:  1.7828459901904616e-18
# transition_prob:  2.9203421423535307e-18
# transition_prob:  1.7684660894619547e-12
# transition_prob:  7.645203392474204e-14
# transition_prob:  5.264290101727198e-19
# max_prob:  1.0001768466089462e-16
# transition_prob:  1.1137233823858852e-17
# transition_prob:  2.401030669054088e-17
# transition_prob:  1.9163116970426496e-18
# transition_prob:  5.6433376627685526e-18
# transition_prob:  5.748059806905704e-18
# transition_prob:  9.798317853901307e-19
# transition_prob:  1.3767938446667969e-17
# transition_prob:  1.3121637026804702e-18
# transition_prob:  4.666780884748308e-18
# transition_prob:  1.001112001418302e-11
# transition_prob:  2.5484011308247345e-14
# transition_prob:  5.949483416555183e-18
# max_prob:  1.0010011120014183e-16
# transition_prob:  1.959431447125447e-17
# transition_prob:  6.4032973832912524e-18
# transition_prob:  6.220221418378658e-17
# transition_prob:  1.7624209349791503e-18
# transition_prob:  1.8426916260468993e-17
# transition_prob:  7.081002536340158e-17
# transition_prob:  2.4150208569661554e-17
# transition_prob:  1.5889631990853283e-17
# transition_prob:  1.2396694500850978e-17
# transition_prob:  5.041920007143022e-12
# transition_prob:  5.351642374731943e-13
# transition_prob:  4.604164835002676e-18
# max_prob:  1.0005041920007143e-16
# transition_prob:  6.747949919198133e-18
# transition_prob:  1.0228441883868582e-18
# transition_prob:  6.865028716878063e-19
# transition_prob:  3.755243248554896e-19
# transition_prob:  5.47110283629559e-18
# transition_prob:  8.398558160486835e-19
# transition_prob:  4.781866196283189e-18
# transition_prob:  1.978963609986291e-18
# transition_prob:  7.44982438383181e-18
# transition_prob:  8.471353055479852e-12
# transition_prob:  5.946269305257714e-14
# transition_prob:  8.773816836211997e-19
# max_prob:  2.4447030263669463e-11
# transition_prob:  9.198469408571494e-18
# transition_prob:  1.7831156736726178e-18
# transition_prob:  3.520959513687154e-18
# transition_prob:  9.634966741312163e-19
# transition_prob:  1.0357366015049722e-17
# transition_prob:  5.352172064092065e-18
# transition_prob:  9.664098054335382e-18
# transition_prob:  2.653517004586366e-18
# transition_prob:  7.018706643963915e-18
# transition_prob:  1.858048698284521e-12
# transition_prob:  8.494670436082449e-14
# transition_prob:  2.0806479925874165e-18
# max_prob:  1.0001858048698285e-16
# transition_prob:  2.4403499975165242e-17
# transition_prob:  6.261672803360763e-17
# transition_prob:  3.647309735470186e-18
# transition_prob:  6.530831804219854e-17
# transition_prob:  9.787645596598642e-18
# transition_prob:  9.060262742828222e-19
# transition_prob:  3.2518474413157138e-18
# transition_prob:  1.5058184500416544e-17
# transition_prob:  1.3415450433914596e-17
# transition_prob:  3.147089743589e-11
# transition_prob:  5.181748966010294e-13
# transition_prob:  3.793631279657377e-17
# max_prob:  1.0031470897435891e-16
# transition_prob:  2.0240569276350255e-18
# transition_prob:  1.299140203496725e-18
# transition_prob:  7.812655380250803e-18
# transition_prob:  1.0079312257177025e-17
# transition_prob:  8.06542681657644e-18
# transition_prob:  1.0243695938169548e-17
# transition_prob:  1.7042089368376796e-17
# transition_prob:  2.8462139682229664e-17
# transition_prob:  1.7350429550033648e-17
# transition_prob:  1.1888139147277027e-12
# transition_prob:  2.539906460388652e-12
# transition_prob:  2.7466224705360795e-17
# max_prob:  1.0002539906460389e-16
# transition_prob:  7.236741624575148e-18
# transition_prob:  9.1122791738221e-19
# transition_prob:  9.008770813130171e-18
# transition_prob:  8.779190192239095e-18
# transition_prob:  1.7046254836261248e-17
# transition_prob:  5.532868315423751e-18
# transition_prob:  1.4075726476092914e-17
# transition_prob:  2.4542979898728348e-17
# transition_prob:  1.0463529603608959e-17
# transition_prob:  2.5104208731217974e-12
# transition_prob:  5.096802261649469e-13
# transition_prob:  1.3077165093973119e-17
# max_prob:  1.0002510420873122e-16
# transition_prob:  5.904866239453883e-20
# transition_prob:  1.4546710729294316e-19
# transition_prob:  8.423348118868789e-21
# transition_prob:  5.086783683301452e-20
# transition_prob:  1.9929906073680707e-20
# transition_prob:  2.5450176243899503e-21
# transition_prob:  1.1151740196555946e-20
# transition_prob:  3.6486999031782275e-20
# transition_prob:  1.977100463088427e-19
# transition_prob:  5.164173920359701e-14
# transition_prob:  4.595616705920605e-12
# transition_prob:  2.506804810346285e-20
# max_prob:  1.0004595616705921e-16
# transition_prob:  1.896118159113525e-18
# transition_prob:  9.661211654172828e-19
# transition_prob:  5.348826055481682e-19
# transition_prob:  7.256147312944719e-19
# transition_prob:  8.975330114561034e-19
# transition_prob:  1.0434572259998796e-19
# transition_prob:  1.3538212598618917e-18
# transition_prob:  8.218696531908957e-19
# transition_prob:  2.004560191742433e-18
# transition_prob:  3.6897495704447574e-12
# transition_prob:  8.49467043608245e-15
# transition_prob:  2.2227002651737056e-18
# max_prob:  1.0003689749570444e-16
# transition_prob:  2.2955867720236523e-20
# transition_prob:  5.979240090747626e-20
# transition_prob:  1.2046263713053089e-18
# transition_prob:  3.7841720547948e-18
# transition_prob:  1.4618235576762128e-18
# transition_prob:  2.7683865097419423e-13
# transition_prob:  1.7018080171167833e-18
# transition_prob:  6.005653461647705e-18
# transition_prob:  1.12275785475984e-17
# transition_prob:  1.903904874150671e-19
# transition_prob:  2.21503961993489e-18
# transition_prob:  3.962022845334551e-18
# max_prob:  1.0000276838650975e-16
# transition_prob:  1.519022561144794e-17
# transition_prob:  5.896450612568042e-19
# transition_prob:  8.407112717221666e-18
# transition_prob:  5.885158755577192e-19
# transition_prob:  1.627377823371686e-17
# transition_prob:  4.2303434306169006e-13
# transition_prob:  7.326919182475273e-18
# transition_prob:  1.5606105128684172e-18
# transition_prob:  1.1023291186065591e-17
# transition_prob:  4.558813680023138e-17
# transition_prob:  5.537599049837225e-19
# transition_prob:  1.2788807918484943e-18
# max_prob:  1.0000423034343061e-16
# transition_prob:  2.5185866298773787e-18
# transition_prob:  2.0605381235807203e-19
# transition_prob:  1.0614190404508316e-18
# transition_prob:  1.952734609993043e-18
# transition_prob:  6.526684972500797e-18
# transition_prob:  5.810501123817919e-13
# transition_prob:  2.8883897538220634e-18
# transition_prob:  1.7868853236094446e-18
# transition_prob:  2.9162363622837703e-18
# transition_prob:  1.4521601721931026e-18
# transition_prob:  8.306398574755839e-19
# transition_prob:  5.265979731140859e-19
# max_prob:  1.0000581050112382e-16
# transition_prob:  1.1133595844314715e-17
# transition_prob:  2.414141183716626e-17
# transition_prob:  1.9164510452584456e-18
# transition_prob:  5.6485544086608565e-18
# transition_prob:  5.745626050941655e-18
# transition_prob:  2.395120912922804e-13
# transition_prob:  1.3768362896018222e-17
# transition_prob:  1.3151366272766365e-18
# transition_prob:  4.660219743959819e-18
# transition_prob:  8.220541999798737e-18
# transition_prob:  2.7687995249186125e-19
# transition_prob:  5.9513929659877645e-18
# max_prob:  1.0000239512091294e-16
# transition_prob:  1.9587913984710393e-17
# transition_prob:  6.4382617530988664e-18
# transition_prob:  6.220673733499337e-17
# transition_prob:  1.7640501308065987e-18
# transition_prob:  1.8419114216152393e-17
# transition_prob:  1.7308947833831473e-11
# transition_prob:  2.4150953092189423e-17
# transition_prob:  1.5925632588700292e-17
# transition_prob:  1.2379265686441074e-17
# transition_prob:  4.1401276899712765e-18
# transition_prob:  5.814479002329087e-18
# transition_prob:  4.605642590251767e-18
# max_prob:  1.0017308947833832e-16
# transition_prob:  6.745745700075219e-18
# transition_prob:  1.0284292956085916e-18
# transition_prob:  6.86552792037641e-19
# transition_prob:  3.7587146250632957e-19
# transition_prob:  5.468786345235117e-18
# transition_prob:  2.0529607825052605e-13
# transition_prob:  4.782013615594212e-18
# transition_prob:  1.983447280414781e-18
# transition_prob:  7.439350494476605e-18
# transition_prob:  6.956176081101405e-18
# transition_prob:  6.460532224810097e-19
# transition_prob:  8.776632885234765e-19
# max_prob:  1.000020529607825e-16
# transition_prob:  9.195464726791888e-18
# transition_prob:  1.7928521441334033e-18
# transition_prob:  3.521215546892441e-18
# transition_prob:  9.643873380640487e-19
# transition_prob:  1.0352980656831862e-17
# transition_prob:  1.3082959168510797e-12
# transition_prob:  9.664395987112741e-18
# transition_prob:  2.6595289876591833e-18
# transition_prob:  7.008838873528271e-18
# transition_prob:  1.525720133239833e-18
# transition_prob:  9.22933174972871e-19
# transition_prob:  2.08131579849853e-18
# max_prob:  1.0001308295916852e-16
# transition_prob:  2.4395528567262784e-17
# transition_prob:  6.295863850629984e-17
# transition_prob:  3.6475749564699215e-18
# transition_prob:  6.536868956703705e-17
# transition_prob:  9.783501460725856e-18
# transition_prob:  2.214709207793554e-13
# transition_prob:  3.2519476919479296e-18
# transition_prob:  1.509230131601162e-17
# transition_prob:  1.3396589325752101e-17
# transition_prob:  2.5842047021369627e-17
# transition_prob:  5.629892367334513e-18
# transition_prob:  3.7948488856157937e-17
# max_prob:  1.000022147092078e-16
# transition_prob:  2.0233957690551336e-18
# transition_prob:  1.306233989055635e-18
# transition_prob:  7.81322349220751e-18
# transition_prob:  1.0088629653008534e-17
# transition_prob:  8.062011876357158e-18
# transition_prob:  2.503990045328386e-12
# transition_prob:  1.7042614755949334e-17
# transition_prob:  2.8526625382411715e-17
# transition_prob:  1.7326036158993892e-17
# transition_prob:  9.76183953655435e-19
# transition_prob:  2.759570193168884e-17
# transition_prob:  2.7475040279777783e-17
# max_prob:  3.3483405171773374e-09
# transition_prob:  7.234377741548826e-18
# transition_prob:  9.16203558520713e-19
# transition_prob:  9.009425902874321e-18
# transition_prob:  8.787305744968692e-18
# transition_prob:  1.7039037370583072e-17
# transition_prob:  1.3524656791413445e-12
# transition_prob:  1.4076160414186134e-17
# transition_prob:  2.4598586092113435e-17
# transition_prob:  1.0448818672761924e-17
# transition_prob:  2.061409731921317e-18
# transition_prob:  5.5375990498372254e-18
# transition_prob:  1.3081362347992769e-17
# max_prob:  1.0001352465679141e-16
# transition_prob:  5.902937413775106e-20
# transition_prob:  1.4626141145059576e-19
# transition_prob:  8.423960638498663e-21
# transition_prob:  5.091485946300878e-20
# transition_prob:  1.992146765630177e-20
# transition_prob:  6.221093280318972e-16
# transition_prob:  1.115208399159098e-20
# transition_prob:  3.6569666382388217e-20
# transition_prob:  1.9743208094445837e-19
# transition_prob:  4.240515401517403e-20
# transition_prob:  4.9930684766032316e-17
# transition_prob:  2.5076093957813616e-20
# max_prob:  1.0000000622109329e-16
# transition_prob:  1.8954987917566733e-18
# transition_prob:  9.71396543973768e-19
# transition_prob:  5.349215005446652e-19
# transition_prob:  7.262854952811547e-19
# transition_prob:  8.971529916941418e-19
# transition_prob:  2.5506482449307785e-14
# transition_prob:  1.3538629965791449e-18
# transition_prob:  8.237317352632946e-19
# transition_prob:  2.0017419317979806e-18
# transition_prob:  3.0298049838188633e-18
# transition_prob:  9.229331749728709e-20
# transition_prob:  2.2234136642594735e-18
# max_prob:  1.000002550648245e-16
# transition_prob:  2.295597096824189e-20
# transition_prob:  5.946479350418513e-20
# transition_prob:  1.2044833573368742e-18
# transition_prob:  3.780478008385773e-18
# transition_prob:  1.4636158770291047e-18
# transition_prob:  1.1324252122947863e-18
# transition_prob:  1.7017144771278811e-18
# transition_prob:  5.986945016152145e-18
# transition_prob:  3.7584210122904823e-10
# transition_prob:  1.9036844658286491e-19
# transition_prob:  2.2140222779577846e-18
# transition_prob:  3.960571599325435e-18
# max_prob:  1.037584210122905e-16
# transition_prob:  1.5190293932128064e-17
# transition_prob:  5.864143482489642e-19
# transition_prob:  8.406114619735667e-18
# transition_prob:  5.879413760568298e-19
# transition_prob:  1.6293731262603143e-17
# transition_prob:  1.7304475154167518e-18
# transition_prob:  7.326516457883473e-18
# transition_prob:  1.5557489941500549e-18
# transition_prob:  3.6900360164629965e-10
# transition_prob:  4.5582859223146176e-17
# transition_prob:  5.535055694894462e-19
# transition_prob:  1.278412351680995e-18
# max_prob:  1.0369003601646299e-16
# transition_prob:  2.5185979576585392e-18
# transition_prob:  2.0492482684519187e-19
# transition_prob:  1.06129302814298e-18
# transition_prob:  1.950828382641491e-18
# transition_prob:  6.5346872404386854e-18
# transition_prob:  2.376820557940068e-18
# transition_prob:  2.8882309932904407e-18
# transition_prob:  1.7813189273967678e-18
# transition_prob:  9.762072894299495e-11
# transition_prob:  1.4519920607547606e-18
# transition_prob:  8.302583542341694e-19
# transition_prob:  5.26405085986292e-19
# max_prob:  1.0097620728942996e-16
# transition_prob:  1.1133645919597318e-17
# transition_prob:  2.4009139088058997e-17
# transition_prob:  1.916223523035936e-18
# transition_prob:  5.643040382916951e-18
# transition_prob:  5.752670674563642e-18
# transition_prob:  9.797386668168374e-19
# transition_prob:  1.3767606117051652e-17
# transition_prob:  1.3110397938399848e-18
# transition_prob:  1.5600040323330506e-10
# transition_prob:  8.21959033677561e-18
# transition_prob:  2.767527847447231e-19
# transition_prob:  5.94921303527365e-18
# max_prob:  1.0156000403233305e-16
# transition_prob:  1.9588002084758402e-17
# transition_prob:  6.402985995935258e-18
# transition_prob:  6.219935211366537e-17
# transition_prob:  1.7623280941347214e-18
# transition_prob:  1.8441697608449898e-17
# transition_prob:  7.080329591388278e-17
# transition_prob:  2.4149625633474047e-17
# transition_prob:  1.5876022029054998e-17
# transition_prob:  4.1439471632642285e-10
# transition_prob:  4.139648402056481e-18
# transition_prob:  5.811808479639185e-18
# transition_prob:  4.603955593308681e-18
# max_prob:  1.4302944129196635e-13
# transition_prob:  6.745776040239082e-18
# transition_prob:  1.0227944482719844e-18
# transition_prob:  6.8647128407661e-19
# transition_prob:  3.7550454297777167e-19
# transition_prob:  5.475491539957096e-18
# transition_prob:  8.397760001287178e-19
# transition_prob:  4.781750771903247e-18
# transition_prob:  1.9772685663787604e-18
# transition_prob:  2.490315351408983e-10
# transition_prob:  6.95537078924122e-18
# transition_prob:  6.457564977376872e-19
# transition_prob:  8.773418099771535e-19
# max_prob:  1.0249031535140899e-16
# transition_prob:  9.195506084992896e-18
# transition_prob:  1.7830289621485665e-18
# transition_prob:  3.520797506061632e-18
# transition_prob:  9.634459190346015e-19
# transition_prob:  1.0365674286985732e-17
# transition_prob:  5.351663419002102e-18
# transition_prob:  9.663864782955582e-18
# transition_prob:  2.6512441851098475e-18
# transition_prob:  2.3462020044973683e-10
# transition_prob:  1.525543506025413e-18
# transition_prob:  9.225092824824103e-19
# transition_prob:  2.080553435088678e-18
# max_prob:  1.0234620200449737e-16
# transition_prob:  2.439563829039306e-17
# transition_prob:  6.261368303097598e-17
# transition_prob:  3.647141914173892e-18
# transition_prob:  6.530487772934538e-17
# transition_prob:  9.795496861207005e-18
# transition_prob:  9.05940169835829e-19
# transition_prob:  3.2517689484304732e-18
# transition_prob:  1.5045286699138317e-17
# transition_prob:  4.484495263291037e-10
# transition_prob:  2.5839055379140586e-17
# transition_prob:  5.6273066231427034e-18
# transition_prob:  3.793458873615502e-17
# max_prob:  1.0448449526329104e-16
# transition_prob:  2.023404869629321e-18
# transition_prob:  1.2990770273221982e-18
# transition_prob:  7.812295901608048e-18
# transition_prob:  1.0078781298969113e-17
# transition_prob:  8.071896584968785e-18
# transition_prob:  1.0242722425812392e-17
# transition_prob:  1.7041678007515255e-17
# transition_prob:  2.843776097830527e-17
# transition_prob:  5.799873773637176e-10
# transition_prob:  9.760709442975984e-19
# transition_prob:  2.758302754622407e-17
# transition_prob:  2.746497647042765e-17
# max_prob:  1.0579987377363718e-16
# transition_prob:  7.23441027942023e-18
# transition_prob:  9.111836050795137e-19
# transition_prob:  9.008356298404104e-18
# transition_prob:  8.77872772188671e-18
# transition_prob:  1.7059928671912552e-17
# transition_prob:  5.532342497817675e-18
# transition_prob:  1.407538671710886e-17
# transition_prob:  2.45219580765093e-17
# transition_prob:  3.497731900679664e-10
# transition_prob:  2.0611710898199285e-18
# transition_prob:  5.535055694894462e-18
# transition_prob:  1.3076570786802335e-17
# max_prob:  1.0349773190067967e-16
# transition_prob:  5.9029639632622e-20
# transition_prob:  1.454600333410067e-19
# transition_prob:  8.422960540817301e-21
# transition_prob:  5.0865157216112496e-20
# transition_prob:  1.9945893061016934e-20
# transition_prob:  2.544775757965812e-21
# transition_prob:  1.1151471016565408e-20
# transition_prob:  3.6455746787347507e-20
# transition_prob:  6.609019730978502e-12
# transition_prob:  4.2400244920729006e-20
# transition_prob:  4.9907752182298403e-17
# transition_prob:  2.5066908856490102e-20
# max_prob:  1.0006609019730978e-16
# transition_prob:  1.8955073170919736e-18
# transition_prob:  9.660741836987616e-19
# transition_prob:  5.348579943418987e-19
# transition_prob:  7.255765073474871e-19
# transition_prob:  8.982529771616591e-19
# transition_prob:  1.0433580607659828e-19
# transition_prob:  1.3537885814110406e-18
# transition_prob:  8.211656963850026e-19
# transition_prob:  6.700811671686537e-11
# transition_prob:  3.029454234030046e-18
# transition_prob:  9.225092824824104e-20
# transition_prob:  2.222599251942122e-18
# max_prob:  1.0067008116716867e-16
# transition_prob:  2.3818093627796727e-20
# transition_prob:  6.16564575217046e-20
# transition_prob:  1.21617094604468e-18
# transition_prob:  3.839361660404004e-18
# transition_prob:  2.089784414633557e-15
# transition_prob:  1.160602344488816e-18
# transition_prob:  1.741412308039861e-18
# transition_prob:  6.255290745317216e-18
# transition_prob:  1.1875747602389347e-17
# transition_prob:  1.970003808424354e-19
# transition_prob:  2.2154853918223566e-18
# transition_prob:  3.98710047403392e-18
# max_prob:  1.0000002089784415e-16
# transition_prob:  1.5760772811993495e-17
# transition_prob:  6.080275272525022e-19
# transition_prob:  8.487682546521613e-18
# transition_prob:  5.9709898398843425e-19
# transition_prob:  2.326456427757e-14
# transition_prob:  1.7735047061851568e-18
# transition_prob:  7.49743044811395e-18
# transition_prob:  1.6254804844354525e-18
# transition_prob:  1.1659666714276513e-17
# transition_prob:  4.7170845736444605e-17
# transition_prob:  5.538713479555892e-19
# transition_prob:  1.286975469466645e-18
# max_prob:  1.0000023264564278e-16
# transition_prob:  2.6131851294496984e-18
# transition_prob:  2.1247763822864353e-19
# transition_prob:  1.0715911832281794e-18
# transition_prob:  1.98121393160539e-18
# transition_prob:  9.330376749733751e-15
# transition_prob:  2.4359608758484365e-18
# transition_prob:  2.9556080457557277e-18
# transition_prob:  1.8611608710188002e-18
# transition_prob:  3.084590932993301e-18
# transition_prob:  1.5025756320618483e-18
# transition_prob:  8.308070219333838e-19
# transition_prob:  5.299310756627362e-19
# max_prob:  1.0000009330376751e-16
# transition_prob:  1.1551775409481414e-17
# transition_prob:  2.4894031864609467e-17
# transition_prob:  1.9348174141619905e-18
# transition_prob:  5.730934777619272e-18
# transition_prob:  8.21379550939618e-15
# transition_prob:  1.0041166351195374e-18
# transition_prob:  1.408877873857151e-17
# transition_prob:  1.3698029741420026e-18
# transition_prob:  4.929254622117645e-18
# transition_prob:  8.505939171010429e-18
# transition_prob:  2.769356739777946e-19
# transition_prob:  5.989062315426478e-18
# max_prob:  1.0000008213795509e-16
# transition_prob:  2.032363903411855e-17
# transition_prob:  6.638977633760161e-18
# transition_prob:  6.280289755990866e-17
# transition_prob:  1.7897776161281824e-18
# transition_prob:  2.6331480032692464e-14
# transition_prob:  7.256503152969062e-17
# transition_prob:  2.471299144358534e-17
# transition_prob:  1.65876141175298e-17
# transition_prob:  1.3093921736716745e-17
# transition_prob:  4.283862827046414e-18
# transition_prob:  5.815649153533686e-18
# transition_prob:  4.634794010955041e-18
# max_prob:  1.0000026331480033e-16
# transition_prob:  6.999116941768269e-18
# transition_prob:  1.060491069373319e-18
# transition_prob:  6.931323923261636e-19
# transition_prob:  3.8135329511729517e-19
# transition_prob:  7.818032765459467e-15
# transition_prob:  8.606714015310321e-19
# transition_prob:  4.893300115907552e-18
# transition_prob:  2.065893328050799e-18
# transition_prob:  7.868824824833876e-18
# transition_prob:  7.197677550961344e-18
# transition_prob:  6.461832392815207e-19
# transition_prob:  8.832184594378936e-19
# max_prob:  1.0000007818032766e-16
# transition_prob:  9.540847790334575e-18
# transition_prob:  1.8487451647661887e-18
# transition_prob:  3.554961226899833e-18
# transition_prob:  9.784522791057294e-19
# transition_prob:  1.4800348173375157e-14
# transition_prob:  5.484824113393213e-18
# transition_prob:  9.889304758501596e-18
# transition_prob:  2.770077755842256e-18
# transition_prob:  7.413459731763872e-18
# transition_prob:  1.578689415569153e-18
# transition_prob:  9.231189132593153e-19
# transition_prob:  2.0944894895241475e-18
# max_prob:  7.1340502768365534e-12
# transition_prob:  2.5311828356739982e-17
# transition_prob:  6.492140408770008e-17
# transition_prob:  3.6825316058555696e-18
# transition_prob:  6.63220479619927e-17
# transition_prob:  1.3986235729892442e-14
# transition_prob:  9.284818755910528e-19
# transition_prob:  3.327626664642356e-18
# transition_prob:  1.5719643724112743e-17
# transition_prob:  1.4169975555372612e-17
# transition_prob:  2.673921987425438e-17
# transition_prob:  5.631025370881824e-18
# transition_prob:  3.81886838652194e-17
# max_prob:  2.2718724662536812e-13
# transition_prob:  2.099394824050083e-18
# transition_prob:  1.346956456628008e-18
# transition_prob:  7.888101765429655e-18
# transition_prob:  1.0235765534682142e-17
# transition_prob:  1.1525239610027925e-14
# transition_prob:  1.0497583003522436e-17
# transition_prob:  1.743922863136642e-17
# transition_prob:  2.971239297926023e-17
# transition_prob:  1.8326269685113468e-17
# transition_prob:  1.0100746799557598e-18
# transition_prob:  2.7601255506453527e-17
# transition_prob:  2.764894358259387e-17
# max_prob:  1.0000011525239611e-16
# transition_prob:  7.506102077559941e-18
# transition_prob:  9.447666414095043e-19
# transition_prob:  9.095768019543953e-18
# transition_prob:  8.915462692224255e-18
# transition_prob:  2.435855856229828e-14
# transition_prob:  5.669998869480193e-18
# transition_prob:  1.4403739287076755e-17
# transition_prob:  2.562107669257193e-17
# transition_prob:  1.1052029854415583e-17
# transition_prob:  2.1329768507576415e-18
# transition_prob:  5.538713479555892e-18
# transition_prob:  1.3164160847812414e-17
# max_prob:  1.0000024358558563e-16
# transition_prob:  6.12465264714773e-20
# transition_prob:  1.5082118070693892e-19
# transition_prob:  8.504691930382377e-21
# transition_prob:  5.1657418462103727e-20
# transition_prob:  2.847920489867159e-17
# transition_prob:  2.6080951561546428e-21
# transition_prob:  1.141161407627694e-20
# transition_prob:  3.8089759447813766e-20
# transition_prob:  2.088298515989823e-19
# transition_prob:  4.3877357551269706e-20
# transition_prob:  4.9940733207328964e-17
# transition_prob:  2.5234813126796962e-20
# max_prob:  1.0000000049940734e-16
# transition_prob:  1.9666940166952156e-18
# transition_prob:  1.0016802945064623e-18
# transition_prob:  5.400479375792809e-19
# transition_prob:  7.368778810035385e-19
# transition_prob:  1.2825462619884517e-15
# transition_prob:  1.0693190140234035e-19
# transition_prob:  1.3853699488600206e-18
# transition_prob:  8.57971831562005e-19
# transition_prob:  2.1173026620452374e-18
# transition_prob:  3.1349924242243927e-18
# transition_prob:  9.231189132593153e-20
# transition_prob:  2.2374867639093304e-18
# max_prob:  1.0000001282546262e-16
# transition_prob:  2.2955340273001543e-20
# transition_prob:  5.946241638201112e-20
# transition_prob:  1.2044144986472462e-18
# transition_prob:  3.780390568668001e-18
# transition_prob:  1.4610907366122772e-18
# transition_prob:  1.1324028498421204e-18
# transition_prob:  1.213852855791604e-13
# transition_prob:  1.3601274310496226e-14
# transition_prob:  1.1224740508558313e-17
# transition_prob:  1.9034316703289328e-19
# transition_prob:  2.2140221512783913e-18
# transition_prob:  3.960562005286537e-18
# max_prob:  1.0000121385285579e-16
# transition_prob:  1.5189876592077595e-17
# transition_prob:  5.8639090616721725e-19
# transition_prob:  8.405634053496166e-18
# transition_prob:  5.879277773987038e-19
# transition_prob:  1.6265620089447767e-17
# transition_prob:  1.7304133435789703e-18
# transition_prob:  5.226089949246946e-13
# transition_prob:  3.5343850278607184e-15
# transition_prob:  1.102050478554266e-17
# transition_prob:  4.557680614981251e-17
# transition_prob:  5.535055378195978e-19
# transition_prob:  1.278409254870971e-18
# max_prob:  1.0000522608994926e-16
# transition_prob:  2.518528761380741e-18
# transition_prob:  2.049166349164691e-19
# transition_prob:  1.0612323554514197e-18
# transition_prob:  1.9507832613941722e-18
# transition_prob:  6.523413105523141e-18
# transition_prob:  2.3767736219158215e-18
# transition_prob:  2.0602089754261172e-13
# transition_prob:  4.046839799035603e-15
# transition_prob:  2.9154992137872184e-18
# transition_prob:  1.4517992467327042e-18
# transition_prob:  8.302583067293967e-19
# transition_prob:  5.264038108292233e-19
# max_prob:  1.4649859275189583e-10
# transition_prob:  1.113334003240575e-17
# transition_prob:  2.4008179315838457e-17
# transition_prob:  1.916113975120619e-18
# transition_prob:  5.642909863480688e-18
# transition_prob:  5.7427457335644196e-18
# transition_prob:  9.79719319526329e-19
# transition_prob:  9.820594598691444e-13
# transition_prob:  2.978449245798268e-15
# transition_prob:  4.6590417619476994e-18
# transition_prob:  8.21849883475206e-18
# transition_prob:  2.767527689097989e-19
# transition_prob:  5.949198623974715e-18
# max_prob:  1.0000982059459869e-16
# transition_prob:  1.9587463921519745e-17
# transition_prob:  6.402730034733782e-18
# transition_prob:  6.219579626056356e-17
# transition_prob:  1.7622873327625267e-18
# transition_prob:  1.8409880601872644e-17
# transition_prob:  7.080189773293778e-17
# transition_prob:  1.7226210645493432e-12
# transition_prob:  3.606749853123596e-14
# transition_prob:  1.2376136530928443e-17
# transition_prob:  4.1390986867516425e-18
# transition_prob:  5.811808147105777e-18
# transition_prob:  4.603944440744477e-18
# max_prob:  1.000172262106455e-16
# transition_prob:  6.74559070593774e-18
# transition_prob:  1.0227535617705913e-18
# transition_prob:  6.864320394388151e-19
# transition_prob:  3.7549585782970644e-19
# transition_prob:  5.4660448092905724e-18
# transition_prob:  8.397594167368533e-19
# transition_prob:  3.410878797925556e-13
# transition_prob:  4.492002529551159e-15
# transition_prob:  7.437470020690855e-18
# transition_prob:  6.954447166410891e-18
# transition_prob:  6.457564607895308e-19
# transition_prob:  8.773396847153724e-19
# max_prob:  1.0000341087879793e-16
# transition_prob:  9.195253446499476e-18
# transition_prob:  1.7829576850544563e-18
# transition_prob:  3.520596226815027e-18
# transition_prob:  9.634236352284102e-19
# transition_prob:  1.0347790644494186e-17
# transition_prob:  5.351557737568492e-18
# transition_prob:  6.893347869128468e-13
# transition_prob:  6.0231552700918746e-15
# transition_prob:  7.007067221852497e-18
# transition_prob:  1.5253409249045039e-18
# transition_prob:  9.225092296993296e-19
# transition_prob:  2.0805483951821684e-18
# max_prob:  1.0000689334786913e-16
# transition_prob:  2.439496804155121e-17
# transition_prob:  6.261118003104007e-17
# transition_prob:  3.646933411987816e-18
# transition_prob:  6.530336727483006e-17
# transition_prob:  9.778596931781979e-18
# transition_prob:  9.059222798736965e-19
# transition_prob:  2.319524854186316e-13
# transition_prob:  3.4180215606282796e-14
# transition_prob:  1.3393203017355387e-17
# transition_prob:  2.5835624139860116e-17
# transition_prob:  5.627306301165911e-18
# transition_prob:  3.793449684388371e-17
# max_prob:  4.5518441562350807e-14
# transition_prob:  2.0233492783488503e-18
# transition_prob:  1.2990250963454735e-18
# transition_prob:  7.811849283184062e-18
# transition_prob:  1.0078548184058694e-17
# transition_prob:  8.05797034063989e-18
# transition_prob:  1.0242520158684348e-17
# transition_prob:  1.215602840249495e-12
# transition_prob:  6.460553534377509e-14
# transition_prob:  1.7321656588918235e-17
# transition_prob:  9.75941329150471e-19
# transition_prob:  2.7583025968009957e-17
# transition_prob:  2.7464909939613607e-17
# max_prob:  1.0001215602840249e-16
# transition_prob:  7.234211520320201e-18
# transition_prob:  9.111471802535856e-19
# transition_prob:  9.00784130281979e-18
# transition_prob:  8.778524676273774e-18
# transition_prob:  1.7030495597241972e-17
# transition_prob:  5.532233248442179e-18
# transition_prob:  1.0040138103408668e-12
# transition_prob:  5.570952756861188e-14
# transition_prob:  1.0446177483908036e-17
# transition_prob:  2.0608973812379626e-18
# transition_prob:  5.535055378195978e-18
# transition_prob:  1.3076539110281501e-17
# max_prob:  1.3190296459922585e-09
# transition_prob:  5.90280178448611e-20
# transition_prob:  1.4545421853445796e-19
# transition_prob:  8.422479011519203e-21
# transition_prob:  5.0863980741872586e-20
# transition_prob:  1.9911480903080843e-20
# transition_prob:  2.5447255052631923e-21
# transition_prob:  7.954474808595047e-16
# transition_prob:  8.282097311917324e-17
# transition_prob:  1.973821752634506e-19
# transition_prob:  4.239461447550805e-20
# transition_prob:  4.9907749326733735e-17
# transition_prob:  2.5066848134724924e-20
# max_prob:  2.7624411589641877e-11
# transition_prob:  1.8954552396849845e-18
# transition_prob:  9.660355646062114e-19
# transition_prob:  5.348274172314695e-19
# transition_prob:  7.255597252884766e-19
# transition_prob:  8.967032434283994e-19
# transition_prob:  1.0433374571579088e-19
# transition_prob:  9.656732417634387e-14
# transition_prob:  1.8655424195093773e-15
# transition_prob:  2.001235943643319e-18
# transition_prob:  3.029051944464361e-18
# transition_prob:  9.225092296993297e-20
# transition_prob:  2.2225938679456096e-18
# max_prob:  1.0000096567324177e-16
# transition_prob:  2.295561411982654e-20
# transition_prob:  5.946538559774869e-20
# transition_prob:  1.7644486451209554e-12
# transition_prob:  3.780758720062097e-18
# transition_prob:  1.4613385792595258e-18
# transition_prob:  1.1324405893850695e-18
# transition_prob:  1.701609161394736e-18
# transition_prob:  2.7251037154243805e-15
# transition_prob:  1.1226092052862558e-17
# transition_prob:  2.510676686637915e-12
# transition_prob:  6.116105887005581e-13
# ...
# transition_prob:  5.466450207231955e-18
# transition_prob:  8.397779088377219e-19
# transition_prob:  4.781331648769016e-18
# transition_prob:  1.977305433680143e-18
# transition_prob:  7.437711460520075e-18
# transition_prob:  2.4013626688313437e-11
# transition_prob:  6.457565112037679e-19
# transition_prob:  8.773428541002562e-19
# max_prob:  5.197939980364516e-10
# transition_prob:  9.195307571675744e-18
# transition_prob:  1.783074519034978e-18
# transition_prob:  3.52068874971123e-18
# transition_prob:  9.634459244576392e-19
# transition_prob:  1.0348558104910539e-17
# transition_prob:  5.351675582684028e-18
# transition_prob:  9.663017739792978e-18
# transition_prob:  2.651293619071462e-18
# transition_prob:  7.007294689675382e-18
# transition_prob:  5.266984803619879e-12
# transition_prob:  9.225093017196685e-19
# transition_prob:  2.080555911152036e-18
# max_prob:  1.0005266984803621e-16
# transition_prob:  2.4395111635412218e-17
# transition_prob:  6.261528282801023e-17
# transition_prob:  3.647029255083643e-18
# transition_prob:  6.530487809693304e-17
# transition_prob:  9.779322177037747e-18
# transition_prob:  9.059422289279667e-19
# transition_prob:  3.251483929060273e-18
# transition_prob:  1.5045567227099242e-17
# transition_prob:  1.3393637795934692e-17
# transition_prob:  8.921011526993375e-11
# transition_prob:  5.627306740489978e-18
# transition_prob:  3.793463388204917e-17
# max_prob:  1.0089210115269933e-16
# transition_prob:  2.023361188203971e-18
# transition_prob:  1.2991102191019335e-18
# transition_prob:  7.812054582194177e-18
# transition_prob:  1.007878135570049e-17
# transition_prob:  8.058567972877054e-18
# transition_prob:  1.0242745706278275e-17
# transition_prob:  1.7040184294889948e-17
# transition_prob:  2.843829121659584e-17
# transition_prob:  1.7322218895427973e-17
# transition_prob:  3.36991427026842e-12
# transition_prob:  2.7583028121418084e-17
# transition_prob:  2.746500915645278e-17
# max_prob:  1.000336991427027e-16
# transition_prob:  7.234254102395398e-18
# transition_prob:  9.11206886074314e-19
# transition_prob:  9.008078033053017e-18
# transition_prob:  8.778727771300353e-18
# transition_prob:  1.7031758691141994e-17
# transition_prob:  5.532355072161235e-18
# transition_prob:  1.407415300157708e-17
# transition_prob:  2.452241530241896e-17
# transition_prob:  1.0446516594291095e-17
# transition_prob:  7.116255134556184e-12
# transition_prob:  5.535055810318011e-18
# transition_prob:  1.307658634920858e-17
# max_prob:  1.0007116255134557e-16
# transition_prob:  5.902836529606398e-20
# transition_prob:  1.4546374988535735e-19
# transition_prob:  8.422700358160837e-21
# transition_prob:  5.0865157502421946e-20
# transition_prob:  1.991295766985639e-20
# transition_prob:  2.544781541932491e-21
# transition_prob:  1.1150493583882967e-20
# transition_prob:  3.6456426525561527e-20
# transition_prob:  1.9738858280775722e-19
# transition_prob:  1.4638811989641184e-13
# transition_prob:  4.9907753223034066e-17
# transition_prob:  2.5066938688578747e-20
# max_prob:  1.0000146388119898e-16
# transition_prob:  1.8954663967291656e-18
# transition_prob:  9.660988671631281e-19
# transition_prob:  5.348414727432132e-19
# transition_prob:  7.255765114316072e-19
# transition_prob:  8.96769748856291e-19
# transition_prob:  1.0433604321923213e-19
# transition_prob:  1.3536699210833921e-18
# transition_prob:  8.211810074882734e-19
# transition_prob:  2.001300909023094e-18
# transition_prob:  1.0459281790966079e-11
# transition_prob:  9.225093017196684e-20
# transition_prob:  2.222601897053982e-18
# max_prob:  1.0010459281790966e-16
# transition_prob:  2.2956844221644408e-20
# transition_prob:  6.039807273084892e-20
# transition_prob:  1.2050171528768174e-18
# transition_prob:  3.7911155917436604e-18
# transition_prob:  1.4631751128010643e-18
# transition_prob:  5.886157445255897e-12
# transition_prob:  1.7023880448242006e-18
# transition_prob:  6.040220848325414e-18
# transition_prob:  1.1228510208753237e-17
# transition_prob:  1.9047815610953378e-19
# transition_prob:  2.214054550875254e-18
# transition_prob:  3.9647039602013015e-18
# max_prob:  1.0005886157445256e-16
# transition_prob:  1.519087177637956e-17
# transition_prob:  5.956179172380639e-19
# transition_prob:  8.409839990007439e-18
# transition_prob:  5.895957370618356e-19
# transition_prob:  1.6288824446549442e-17
# transition_prob:  8.994577669155078e-12
# transition_prob:  7.329416418410877e-18
# transition_prob:  1.5695930869373546e-18
# transition_prob:  1.102420589551545e-17
# transition_prob:  4.5609128670627367e-17
# transition_prob:  5.535136377188135e-19
# transition_prob:  1.2797462150016861e-18
# max_prob:  1.0008994577669154e-16
# transition_prob:  2.5186937660318437e-18
# transition_prob:  2.0814105064169475e-19
# transition_prob:  1.061763365471881e-18
# transition_prob:  1.95631766190492e-18
# transition_prob:  6.532719335866029e-18
# transition_prob:  1.2354316974986534e-11
# transition_prob:  2.8893742045181387e-18
# transition_prob:  1.7971702919853893e-18
# transition_prob:  2.9164783507165874e-18
# transition_prob:  1.4528288452354442e-18
# transition_prob:  8.302704565782203e-19
# transition_prob:  5.269543238242237e-19
# max_prob:  1.0012354316974986e-16
# transition_prob:  1.1134069447497538e-17
# transition_prob:  2.4385954165359985e-17
# transition_prob:  1.9170727432131186e-18
# transition_prob:  5.658918880909016e-18
# transition_prob:  5.750938272306438e-18
# transition_prob:  5.092518239153978e-12
# transition_prob:  1.3773055571035112e-17
# transition_prob:  1.3227063008549412e-18
# transition_prob:  4.6606064476190315e-18
# transition_prob:  8.22432729492937e-18
# transition_prob:  2.7675681885940675e-19
# transition_prob:  5.955420294648369e-18
# max_prob:  1.0005092518239154e-16
# transition_prob:  1.958874721941172e-17
# transition_prob:  6.503478631434024e-18
# transition_prob:  6.222691724069132e-17
# transition_prob:  1.7672869675797512e-18
# transition_prob:  1.8436143937751377e-17
# transition_prob:  3.680237271895614e-10
# transition_prob:  2.415918446835707e-17
# transition_prob:  1.6017297468017134e-17
# transition_prob:  1.2380292914254851e-17
# transition_prob:  4.142034085581862e-18
# transition_prob:  5.811893196047541e-18
# transition_prob:  4.608759244875353e-18
# max_prob:  1.0368023727189563e-16
# transition_prob:  6.746032651988936e-18
# transition_prob:  1.0388468509706014e-18
# transition_prob:  6.867755102060182e-19
# transition_prob:  3.7656114504458196e-19
# transition_prob:  5.473842609496838e-18
# transition_prob:  4.365015633560552e-12
# transition_prob:  4.783643470646247e-18
# transition_prob:  1.994863621623076e-18
# transition_prob:  7.439967809585427e-18
# transition_prob:  6.959379176401966e-18
# transition_prob:  6.457659106719491e-19
# transition_prob:  8.782572063737061e-19
# max_prob:  1.0004365015633561e-16
# transition_prob:  9.195855885355847e-18
# transition_prob:  1.8110129808065316e-18
# transition_prob:  3.522357831486081e-18
# transition_prob:  9.661568821064174e-19
# transition_prob:  1.036255269033122e-17
# transition_prob:  2.781705417387225e-11
# transition_prob:  9.667689905928259e-18
# transition_prob:  2.6748367251908403e-18
# transition_prob:  7.009420464909824e-18
# transition_prob:  1.526422678277764e-18
# transition_prob:  9.225227295313558e-19
# transition_prob:  2.082724232257646e-18
# max_prob:  1.0027817054173874e-16
# transition_prob:  2.4396566309258965e-17
# transition_prob:  6.35963829822271e-17
# transition_prob:  3.648758232137496e-18
# transition_prob:  6.548863387843065e-17
# transition_prob:  9.792546972045467e-18
# transition_prob:  4.708925956204718e-12
# transition_prob:  3.2530560541988005e-18
# transition_prob:  1.517916970073922e-17
# transition_prob:  1.3397700970781275e-17
# transition_prob:  2.5853946452667218e-17
# transition_prob:  5.627388650141271e-18
# transition_prob:  3.797416873272977e-17
# max_prob:  1.0004708925956205e-16
# transition_prob:  2.0234818406792287e-18
# transition_prob:  1.3194655888893147e-18
# transition_prob:  7.815758106945791e-18
# transition_prob:  1.01071411719735e-17
# transition_prob:  8.069465753681057e-18
# transition_prob:  5.323996340933704e-11
# transition_prob:  1.704842339515297e-17
# transition_prob:  2.869081915358103e-17
# transition_prob:  1.7327473868361785e-17
# transition_prob:  9.766334549616097e-19
# transition_prob:  2.7583429612987538e-17
# transition_prob:  2.749363273667021e-17
# max_prob:  1.0053239963409338e-16
# transition_prob:  7.23468547899251e-18
# transition_prob:  9.254843144603926e-19
# transition_prob:  9.012348566445848e-18
# transition_prob:  8.80342947857214e-18
# transition_prob:  1.7054791117442477e-17
# transition_prob:  2.8756193901092854e-11
# transition_prob:  1.4080957995918125e-17
# transition_prob:  2.4740170824333018e-17
# transition_prob:  1.0449685712652144e-17
# transition_prob:  2.0623589447859523e-18
# transition_prob:  5.535136377188135e-18
# transition_prob:  1.309021455214143e-17
# max_prob:  1.0028756193901093e-16
# transition_prob:  5.903188514137133e-20
# transition_prob:  1.477429779108458e-19
# transition_prob:  8.42669337676096e-21
# transition_prob:  5.1008282595680424e-20
# transition_prob:  1.99398864056536e-20
# transition_prob:  1.3227320101698645e-14
# transition_prob:  1.1155884959529494e-20
# transition_prob:  3.678015435119753e-20
# transition_prob:  1.974484638002767e-19
# transition_prob:  4.242468022439616e-20
# transition_prob:  4.990847966764635e-17
# transition_prob:  2.509306303924875e-20
# max_prob:  1.0000013227320102e-16
# transition_prob:  1.8955794228729242e-18
# transition_prob:  9.812363815965608e-19
# transition_prob:  5.350950294243211e-19
# transition_prob:  7.276181487913237e-19
# transition_prob:  8.97982470544262e-19
# transition_prob:  5.423201241696445e-13
# transition_prob:  1.3543244340868805e-18
# transition_prob:  8.284729767607243e-19
# transition_prob:  2.0019080357528056e-18
# transition_prob:  3.031200111543081e-18
# transition_prob:  9.225227295313558e-20
# transition_prob:  2.224918256146722e-18
# max_prob:  1.000054232012417e-16
# transition_prob:  2.2968847347713253e-20
# transition_prob:  5.951576185343876e-20
# transition_prob:  1.2059013453444144e-18
# transition_prob:  3.782312632745957e-18
# transition_prob:  1.5148583536310475e-18
# transition_prob:  1.1328962597544175e-18
# transition_prob:  1.7062249207980432e-18
# transition_prob:  5.989631571308715e-18
# transition_prob:  1.1284487980311023e-17
# transition_prob:  1.908900565541257e-19
# transition_prob:  2.2140250687793583e-18
# transition_prob:  3.9607762865465046e-18
# max_prob:  1.0000000011284487e-16
# transition_prob:  1.519881441637254e-17
# transition_prob:  5.869169745854498e-19
# transition_prob:  8.41601078778829e-18
# transition_prob:  5.882266975342939e-19
# transition_prob:  1.686418909657872e-17
# transition_prob:  1.7311673182764131e-18
# transition_prob:  7.345935602649504e-18
# transition_prob:  1.5564471140544948e-18
# transition_prob:  1.1079165143692836e-17
# transition_prob:  4.570775635981016e-17
# transition_prob:  5.535062671948396e-19
# transition_prob:  1.2784784216067831e-18
# max_prob:  1.0000000045707756e-16
# transition_prob:  2.5200106804348255e-18
# transition_prob:  2.0510047161800434e-19
# transition_prob:  1.0625424441496238e-18
# transition_prob:  1.9517750981799475e-18
# transition_prob:  6.7634723768085434e-18
# transition_prob:  2.3778092283384853e-18
# transition_prob:  2.895886333464569e-18
# transition_prob:  1.78211826855273e-18
# transition_prob:  2.9310179428650076e-18
# transition_prob:  1.4559705222628316e-18
# transition_prob:  8.302594007922594e-19
# transition_prob:  5.264322912498519e-19
# max_prob:  1.0000000006763473e-16
# transition_prob:  1.1139890963640928e-17
# transition_prob:  2.4029717755102256e-17
# transition_prob:  1.9184794130479317e-18
# transition_prob:  5.645778888293528e-18
# transition_prob:  5.954076724516015e-18
# transition_prob:  9.801462022594398e-19
# transition_prob:  1.3804097557124929e-17
# transition_prob:  1.311628104023076e-18
# transition_prob:  4.6838410850014856e-18
# transition_prob:  8.242112032762001e-18
# transition_prob:  2.767531335974198e-19
# transition_prob:  5.9495204979348336e-18
# max_prob:  1.0000000024029717e-16
# transition_prob:  1.9598989315413038e-17
# transition_prob:  6.408474110957197e-18
# transition_prob:  6.227257681605474e-17
# transition_prob:  1.7631833325582655e-18
# transition_prob:  1.9087357629656615e-17
# transition_prob:  7.083274749471272e-17
# transition_prob:  2.421363491795703e-17
# transition_prob:  1.588314616477579e-17
# transition_prob:  1.2442012696816244e-17
# transition_prob:  4.150991047976988e-18
# transition_prob:  5.8118158055458154e-18
# transition_prob:  4.6041935314074344e-18
# max_prob:  1.0000000070832749e-16
# transition_prob:  6.749559856320881e-18
# transition_prob:  1.0236711038791466e-18
# transition_prob:  6.872794380809074e-19
# transition_prob:  3.756867711987475e-19
# transition_prob:  5.667193305101864e-18
# transition_prob:  8.4012531622237695e-19
# transition_prob:  4.794424941272615e-18
# transition_prob:  1.9781558371067523e-18
# transition_prob:  7.477058466377777e-18
# transition_prob:  6.974428520827556e-18
# transition_prob:  6.457573117273129e-19
# transition_prob:  8.773871520830865e-19
# max_prob:  1.000000000747706e-16
# transition_prob:  9.200663994712566e-18
# transition_prob:  1.784557228497725e-18
# transition_prob:  3.524942394083673e-18
# transition_prob:  9.639134687330415e-19
# transition_prob:  1.0728585642656727e-17
# transition_prob:  5.353889515198966e-18
# transition_prob:  9.689479137376044e-18
# transition_prob:  2.6524338926681463e-18
# transition_prob:  7.044364703303205e-18
# transition_prob:  1.5297234986587438e-18
# transition_prob:  9.225104453247326e-19
# transition_prob:  2.0806609606541763e-18
# max_prob:  1.0000000010728586e-16
# transition_prob:  2.4409322202805554e-17
# transition_prob:  6.266735035035469e-17
# transition_prob:  3.651435542196723e-18
# transition_prob:  6.53365694676005e-17
# transition_prob:  1.0138445804705533e-17
# transition_prob:  9.063170078035341e-19
# transition_prob:  3.2603878565184107e-18
# transition_prob:  1.5052038054371178e-17
# transition_prob:  1.3464492863062523e-17
# transition_prob:  2.590985444892158e-17
# transition_prob:  5.6273137164808694e-18
# transition_prob:  3.793654924244964e-17
# max_prob:  1.000000006533657e-16
# transition_prob:  2.0245398305055824e-18
# transition_prob:  1.3001904897212773e-18
# transition_prob:  7.821492991656953e-18
# transition_prob:  1.0083672420581521e-17
# transition_prob:  8.354500769837393e-18
# transition_prob:  1.0246983023621417e-17
# transition_prob:  1.708684747027241e-17
# transition_prob:  2.845052201305529e-17
# transition_prob:  1.741385695532915e-17
# transition_prob:  9.787453808775174e-19
# transition_prob:  2.7583062315209505e-17
# transition_prob:  2.7466395894258144e-17
# max_prob:  3.3475023154560792e-09
# transition_prob:  7.238468178436492e-18
# transition_prob:  9.119645970157691e-19
# transition_prob:  9.018961460460497e-18
# transition_prob:  8.782987941809763e-18
# transition_prob:  1.7657211749748354e-17
# transition_prob:  5.5346437499013566e-18
# transition_prob:  1.4112693938606096e-17
# transition_prob:  2.4532961951230367e-17
# transition_prob:  1.050178079105511e-17
# transition_prob:  2.066818703236034e-18
# transition_prob:  5.535062671948396e-18
# transition_prob:  1.3077246600095526e-17
# max_prob:  1.0000000024532963e-16
# transition_prob:  5.906275032269122e-20
# transition_prob:  1.4558470976456555e-19
# transition_prob:  8.43287654087003e-21
# transition_prob:  5.088984151696181e-20
# transition_prob:  2.0644216285385514e-20
# transition_prob:  2.5458342915829607e-21
# transition_prob:  1.1181028314535015e-20
# transition_prob:  3.6472105777492555e-20
# transition_prob:  1.9843280854375226e-19
# transition_prob:  4.251642168705527e-20
# transition_prob:  4.990781509206804e-17
# transition_prob:  2.5068204345231044e-20
# max_prob:  1.0000000049907815e-16
# transition_prob:  1.8965705381397517e-18
# transition_prob:  9.669022233420202e-19
# transition_prob:  5.354876603452469e-19
# transition_prob:  7.259286216390141e-19
# transition_prob:  9.297016023694302e-19
# transition_prob:  1.0437920595490139e-19
# transition_prob:  1.3573768373845509e-18
# transition_prob:  8.215341826380198e-19
# transition_prob:  2.011888197735266e-18
# transition_prob:  3.037754945436337e-18
# transition_prob:  9.225104453247327e-20
# transition_prob:  2.2227141186104855e-18
# max_prob:  1.0000000003037755e-16
# Time taken in seconds:  0.11152195930480957
# Viterbi Algorithm Accuracy:  97.05882352941177

# %% [markdown]
# Let's print the print the first 10 words and their predicted tags.

# %%
predicted_tags[0:10]
# Out:
# [('I', 'PRON'),
#  ('forced', 'VERB'),
#  ('confidence', 'NOUN'),
#  ('into', 'ADP'),
#  ('myself', 'PRON'),
#  ('.', '.'),
#  ('Falling', 'VERB'),
#  ('somewhere', 'ADV'),
#  ('in', 'ADP'),
#  ('a', 'DET')]

# %% [markdown]
# as well as the mispredicted tags:

# %%
for i, j in zip(predicted_tags, test_run_base):
    if i != j:
        print(i,j)
# Out:
# ('undeniably', 'VERB') ('undeniably', 'ADV')
# ('there', 'PRT') ('there', 'ADV')
# ('that', 'PRON') ('that', 'DET')
# ('wetly', 'NOUN') ('wetly', 'ADV')

# %% [markdown]
# How well does the model predict? Can you make any observations regarding the wrongly-predicted tags?

# %% [markdown]
# ## 3) Robot localisation -- Optional
#
# Another application of HMM application is robot localisation, which is the focus of this exercise.
#
# We have a robot which is deployed to Mars to collect some samples. However, during the landing phase, the connection got temporarily lost and we are not sure where exactly the robot is. Luckily, the map of the area is available and the robot is provided with a sensor that can detect rocky surface.
#
# The aim is to utilised HMM to localise the robot where the hidden variable $z$ is the position of the robot and the observation $x$ is given by the sensor measurement.
# The figure at the top of the lab sheet, taken from Bishop, shows the relation between hidden variables $z$ with the observable variables $x$.
#
# We will achieve this through the discrete case of the Bayes Filter which consists of mainly two steps:
# prediction step and measurement step. Your task will be to implement these two steps which is given by the following pseudocode.
#
# First step:
# $$ \overline{p}_{k,t} = \sum_i p(z_k | u_t, z_i) p_{i, t-1} $$
# where:
# * $\overline{p}_{k,t}$: the predicted belief of the new state $z_k$ at the current time $t$ based on the action (control $u_t$).
# * $p_{i, t-1}$: the belief of state $z_i$ at the previous time step $t_1$
# * $p(z_k | u_t, z_i)$ : the transition probability of moving from state $z_i$ to state $z_k$ when taking action $u_t$.
#
# In the second step, the knowledge from the measurement model $p(x_t | z_k)$ is combined with the predicted belief $\overline{p}_{k,t}$ to obtain the posterior belief $p_{i, t-1}$ of each state. This posterior belief becomes the current belief for the next time step.
#
# $$ p_{i, t} = \eta p(x_t | z_k) \overline{p}_{k,t}  $$
# $p(x_t | z_k)$ is also known as the likelihood, i.e. how likely it is to see an observation given the robot is in location $z_k$. We need to get the likelihood before implementing the belief. Moreover $\eta$ is the normalising term such that the probability adds to 1.

# %% [markdown]
# We provide the implementation of both World and Robot class:

# %%
class World():
    def __init__(self,start=(0,0),N=15):
        self.world = np.zeros((N,N))
        self.world[0,:] = 1
        self.world[-1,:] = 1
        self.world[:,0] = 1
        self.world[:,-1] = 1
        self.world[5, 6:12] = 1
        self.world[6:11, 9] = 1
        self.world[7:10, 6] = 1
        self.world[11, 4:10] = 1
        self.N = N
    
    def get_world(self):
        return self.world
    def set_world(self,N):
        self.world = np.zeros((N,N))
    def show_world(self):
        fig, ax = plt.subplots(figsize=(5,5))
        ax.grid(which='major', axis='both', linestyle='-', color='k', linewidth=1)
        ax.set_xticks(np.arange(-.5, self.N, 1));
        ax.set_yticks(np.arange(-.5, self.N, 1));
#         ax.axis('off')
        im = ax.imshow(self.world)
        plt.colorbar(im)
        plt.show()

# %% [markdown]
# The robot has 4 possible actions: up, down, left and right. Each action will transition the robot in the new state with probability `p_move`. At each state the robot can measure whether the surface is rocky or normal by calling `measurement()` with the sensor's noise value of `p_sense`.

# %%
class Robot:
    def __init__(self, p_move, p_sense, world):
        self.location = np.random.randint(0,world.shape[0],2)
        self.p_move = p_move
        self.p_sense = p_sense
        self.world =  world
        self.N = self.world.shape[0]
        self.possibleActions = ['U', 'D', 'L', 'R']
        self.tracking_error = []
        self.homing_error = []

    # The robot transition are noisy with prob_move to follow the action and (1-p_move) of staying
    # in the same location
    def transition(self,action):
        if (np.random.rand() < self.p_move):
            if(action == 'U' ):
                self.location =  (max(0,self.location[0]-1), self.location[1])
            elif(action == 'R'):
                self.location = (self.location[0], min(self.N-1,self.location[1]+1))
            elif(action == 'D'):
                self.location = (min(self.N-1,self.location[0]+1), self.location[1])
            elif(action == 'L'):
                self.location = (self.location[0], max(0,self.location[1]-1))
            
        return self.location

    # Measurement model which returns 1 when the surface is rocky and 0 otherwise.
    # As in transition model, the sensor can be noisy with p_sense of returning the correct value.
    def measurement(self):
        if (np.random.rand() < self.p_sense):
            return self.world[int(self.location[0]),int(self.location[1])]
        else:
            if self.world[int(self.location[0]),int(self.location[1])] == 0:
                return 1
            else:
                return 0

    # transition model of the robot assuming no noise
    def transition_no_noise(self,location,action):
        if(action == 'U' ):
            location =  (max(0,location[0]-1), location[1])
        elif(action == 'R'):
            location = (location[0], min(self.N-1,location[1]+1))
        elif(action == 'D'):
            location = (min(self.N-1,location[0]+1), location[1])
        elif(action == 'L'):
            location = (location[0], max(0,location[1]-1))
            
        return location

    def visualise_true_position(self):
        x = self.world.copy()
        x[int(self.location[0]),int(self.location[1])] = 0.5
#         x[int(self.home[0]),int(self.home[1])] = 0.7

        return x

# %% [markdown]
# The map is discrete and represented through grids where each grid indicates a position.
# As displayed below, the yellow corresponds to the rocky surface while the purple corresponds to the normal surface. The sensor measurement will output a value of 1 for the rocky surface and a value of 0 for the normal surface.

# %%
world = World(15)
world.show_world()

# %% [markdown]
# Run the following two cells to initialise the robot class and show the starting position.

# %%
p_move = 0.9  # original value 0.9
p_sense = 0.8 # original value 0.8
N = 15
# Initialise belief in position - uniform distribution over world
state_belief = np.ones((N,N))/(N*N)

robot = Robot(p_move,p_sense,world.get_world())

# %%
plt.imshow(robot.visualise_true_position());

# %% [markdown]
# The next cell provides helper functions to visualise the true robot position, the predicted belief, the likelihood and the posterior belief.

# %%
# helper function to visualise 
def show(robot, predicted_state_belief, likelihood, state_belief):
    plt.clf()
    plt.subplot(2,4,1)
    plt.cla()
    plt.imshow(robot.visualise_true_position())
    plt.title('True position in world')
    
    plt.subplot(2,4,2)
    plt.cla()
    plt.imshow(predicted_state_belief)
    plt.title('Predicted belief given action')
    
    plt.subplot(2,4,3)
    plt.cla()
    plt.imshow(likelihood)
    plt.title('Likelihood')
    
    plt.subplot(2,4,4)
    plt.cla()
    plt.imshow(state_belief)
    plt.title('Posterior belief given measurement')

# %% [markdown]
# The next cell contains the main algorithm and your task is to fill the missing lines `to-do` (hint: check the provided pseudocode above).

# %%
# Run the discrete Bayes filter
plt.figure(figsize=(15,9))

N = 15
steps = 100
# Create list of possible states in world (x,y coordinates)
possible_states = np.array(np.meshgrid(np.linspace(0,N-1,N),np.linspace(0,N-1,N))).reshape(2,-1).T

print("possible_states: ", possible_states[:5])
print("possible_states: ", possible_states.shape)

for step in range(steps):
    
    # Sample a random action
    a = np.random.choice(['U','D','L','R'])
    
    # Move the robot according to the action and sense the measurement
    state = robot.transition(a)
    measurement = robot.measurement()
    
    # Make prediction about state belief given action
    predicted_state_belief = np.zeros((N,N))
    
    for state in possible_states.astype(int):
        
        new_state = robot.transition_no_noise(state,a)
        
        #predicted_state_belief[state[0],state[1]] = # TO-DO
        predicted_state_belief[state[0],state[1]] += (1-p_move)*state_belief[state[0],state[1]]
        predicted_state_belief[new_state[0],new_state[1]] += p_move*state_belief[state[0],state[1]]
   
    # Evaluate sensor belief for each possible state
    likelihood = np.zeros((N,N))
    for state in possible_states.astype(int):
        
        match = measurement == world.get_world()[state[0],state[1]]
        #likelihood[state[0],state[1]] = # TO-DO
        likelihood[state[0],state[1]] = match*p_sense + (1-match)*(1-p_sense)
    
    # Compute posterior belief over possible states
    #state_belief = # TO-DO
    state_belief = likelihood*predicted_state_belief
    
    # normalising
    state_belief = (state_belief+1e-15)
    state_belief = state_belief/np.sum(state_belief) 
    
    # Make a function to display
    show(robot, predicted_state_belief, likelihood, state_belief)

    display.clear_output(wait=True)
    display.display(plt.gcf())

# %% [markdown]
# Change the `p_move` and `p_sense` values and re-run the experiment with different values. How these probabilities affect the performance?

# %% [markdown]
# ## Wrap-up

# %% [markdown]
# Congratulations, you have reached the end of this lab. Let's summarise what we have learnt:
# * Understand the role of the HMM components
# * Key applications of HMM such as POS tagger
# * Perform POS tagging through the transition model and the emission model.
# * Implemented the Viterbi algorithm and the discrete Bayes filter algorithm.

# %% [markdown]
# ## References
#
# * COMS30035 Machine Learning
# * Bishop - Pattern Recognition and Machine Learning: Chapter 13 - Sequential Data
# * [Probabilistic Robotics](http://www.probabilistic-robotics.org)
# * University of Edinburgh's Foundations of Natural Language Processing (FNLP) and Decision Making in Robots and Autonomous Agents (DMR) courses
# * [Hussain Mujtaba](https://www.mygreatlearning.com/blog/pos-tagging/)
# * [Neuromatch Academy 2020](https://www.neuromatchacademy.org)

# %% [markdown]
# ## The End :)
#
# <video controls src="gif.mp4" width="200">
